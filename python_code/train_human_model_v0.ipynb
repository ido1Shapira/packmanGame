# %%
import numpy as np
import random
import os
import shutil

# ! pip install split-folders
import splitfolders

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, regularizers
from tensorflow.keras.models import Sequential

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image

import matplotlib.pyplot as plt

rs = 42
def reset_random_seeds(rs):
   os.environ['PYTHONHASHSEED']=str(rs)
   tf.random.set_seed(rs)
   np.random.seed(rs)
   random.seed(rs)
reset_random_seeds(rs)

map_dir = 'map 5'

# %% [markdown]
# remove prev saved database:

# %%
dir_path = './data/humanModel_v0_dataset_split'
if os.path.exists(dir_path):
    shutil.rmtree(dir_path)
else:
    print("File not found in the directory")

# %% [markdown]
# # Part 1 - Data Preprocessing

# %% [markdown]
# ## Split into train , test data

# %%
# train, test split
splitfolders.ratio('./data/humanModel_v0_dataset/', output="./data/humanModel_v0_dataset_split", ratio=(0.8, 0.2))
# Out:
# Copying files: 5790 files [00:00, 15864.68 files/s]

# %% [markdown]
# ### Preprocessing the Training set

# %%
batch_size = 64
IMG_SIZE = 10

datagen = ImageDataGenerator(rescale = 1./255)
train = datagen.flow_from_directory('./data/humanModel_v0_dataset_split/train',
                                          target_size = (IMG_SIZE,IMG_SIZE), batch_size = batch_size, seed=rs, class_mode='sparse')

test = datagen.flow_from_directory('./data/humanModel_v0_dataset_split/val',
                                            target_size = (IMG_SIZE, IMG_SIZE), batch_size = batch_size, seed=rs, class_mode='sparse')
# Out:
# Found 4629 images belonging to 5 classes.
# Found 1161 images belonging to 5 classes.

# %% [markdown]
# ## View some data

# %%
num_classes = 5

model = Sequential([
  layers.Conv2D(8, 4, padding='same', activation='relu', kernel_regularizer=regularizers.l2(0.001), input_shape=[IMG_SIZE,IMG_SIZE,3]),
  layers.Conv2D(16, 4, padding='same', activation='relu', kernel_regularizer=regularizers.l2(0.001)),
  layers.Conv2D(16, 3, padding='same', activation='relu', kernel_regularizer=regularizers.l2(0.001)),
  layers.MaxPooling2D(),
  layers.Conv2D(8, 3, padding='same', activation='relu', kernel_regularizer=regularizers.l2(0.001)),
  layers.Dropout(0.5),
  layers.Flatten(),
  layers.Dense(32, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
  layers.Dense(num_classes, activation='softmax')
])
# Out:
# 2022-03-13 16:31:07.317344: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-13 16:31:07.321490: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-13 16:31:07.321807: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-13 16:31:07.322444: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-03-13 16:31:07.322839: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-13 16:31:07.323115: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-13 16:31:07.323381: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-13 16:31:07.614587: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-13 16:31:07.614909: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-13 16:31:07.615184: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-13 16:31:07.615464: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 11240 MB memory:  -> device: 0, name: NVIDIA TITAN X (Pascal), pci bus id: 0000:01:00.0, compute capability: 6.1

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 10, 10, 8)         392
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 10, 10, 16)        2064
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 10, 10, 16)        2320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 5, 5, 16)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 5, 5, 8)           1160
# _________________________________________________________________
# dropout (Dropout)            (None, 5, 5, 8)           0
# _________________________________________________________________
# flatten (Flatten)            (None, 200)               0
# _________________________________________________________________
# dense (Dense)                (None, 32)                6432
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 165
# =================================================================
# Total params: 12,533
# Trainable params: 12,533
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs=200
history = model.fit(
  train,
  validation_data=test,
  epochs=epochs
)
# Out:
# Epoch 1/200
# 2022-03-13 16:31:07.935522: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# /home/ido/anaconda3/envs/tf-gpu/lib/python3.7/site-packages/keras/backend.py:4907: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   '"`sparse_categorical_crossentropy` received `from_logits=True`, but '
# 2022-03-13 16:31:08.551279: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8302
# 73/73 [==============================] - 2s 13ms/step - loss: 1.5588 - accuracy: 0.3644 - val_loss: 1.4461 - val_accuracy: 0.3859
# Epoch 2/200
# 73/73 [==============================] - 1s 11ms/step - loss: 1.3225 - accuracy: 0.4666 - val_loss: 1.1500 - val_accuracy: 0.6107
# Epoch 3/200
# 73/73 [==============================] - 1s 11ms/step - loss: 1.1086 - accuracy: 0.6092 - val_loss: 0.9669 - val_accuracy: 0.6710
# Epoch 4/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.9646 - accuracy: 0.6816 - val_loss: 0.8461 - val_accuracy: 0.7227
# Epoch 5/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.8855 - accuracy: 0.7189 - val_loss: 0.7934 - val_accuracy: 0.7252
# Epoch 6/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.8382 - accuracy: 0.7364 - val_loss: 0.7604 - val_accuracy: 0.7502
# Epoch 7/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.7917 - accuracy: 0.7537 - val_loss: 0.7407 - val_accuracy: 0.7580
# Epoch 8/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.7892 - accuracy: 0.7529 - val_loss: 0.7247 - val_accuracy: 0.7649
# Epoch 9/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.7598 - accuracy: 0.7682 - val_loss: 0.7000 - val_accuracy: 0.7649
# Epoch 10/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.7300 - accuracy: 0.7773 - val_loss: 0.6932 - val_accuracy: 0.7812
# Epoch 11/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.7130 - accuracy: 0.7853 - val_loss: 0.6949 - val_accuracy: 0.7657
# Epoch 12/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.7044 - accuracy: 0.7851 - val_loss: 0.6704 - val_accuracy: 0.7933
# Epoch 13/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.6829 - accuracy: 0.8008 - val_loss: 0.6567 - val_accuracy: 0.8036
# Epoch 14/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.6913 - accuracy: 0.7965 - val_loss: 0.6412 - val_accuracy: 0.8165
# Epoch 15/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.6725 - accuracy: 0.8058 - val_loss: 0.6377 - val_accuracy: 0.8088
# Epoch 16/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.6551 - accuracy: 0.8125 - val_loss: 0.6312 - val_accuracy: 0.8200
# Epoch 17/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.6469 - accuracy: 0.8172 - val_loss: 0.6255 - val_accuracy: 0.8217
# Epoch 18/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.6306 - accuracy: 0.8203 - val_loss: 0.6141 - val_accuracy: 0.8208
# Epoch 19/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.6223 - accuracy: 0.8265 - val_loss: 0.6129 - val_accuracy: 0.8260
# Epoch 20/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.6255 - accuracy: 0.8242 - val_loss: 0.6190 - val_accuracy: 0.8269
# Epoch 21/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.6091 - accuracy: 0.8313 - val_loss: 0.6205 - val_accuracy: 0.8295
# Epoch 22/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.6034 - accuracy: 0.8319 - val_loss: 0.6144 - val_accuracy: 0.8234
# Epoch 23/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.5969 - accuracy: 0.8330 - val_loss: 0.5875 - val_accuracy: 0.8346
# Epoch 24/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.5836 - accuracy: 0.8384 - val_loss: 0.5899 - val_accuracy: 0.8286
# Epoch 25/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.5756 - accuracy: 0.8458 - val_loss: 0.6205 - val_accuracy: 0.8200
# Epoch 26/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.5737 - accuracy: 0.8391 - val_loss: 0.6093 - val_accuracy: 0.8183
# Epoch 27/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.5882 - accuracy: 0.8367 - val_loss: 0.5751 - val_accuracy: 0.8303
# Epoch 28/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.5626 - accuracy: 0.8486 - val_loss: 0.5877 - val_accuracy: 0.8320
# Epoch 29/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.5761 - accuracy: 0.8358 - val_loss: 0.5805 - val_accuracy: 0.8398
# Epoch 30/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.5593 - accuracy: 0.8466 - val_loss: 0.5846 - val_accuracy: 0.8389
# Epoch 31/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.5568 - accuracy: 0.8501 - val_loss: 0.5807 - val_accuracy: 0.8389
# Epoch 32/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.5583 - accuracy: 0.8486 - val_loss: 0.5907 - val_accuracy: 0.8381
# Epoch 33/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.5495 - accuracy: 0.8529 - val_loss: 0.5678 - val_accuracy: 0.8398
# Epoch 34/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.5401 - accuracy: 0.8546 - val_loss: 0.5755 - val_accuracy: 0.8398
# Epoch 35/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.5407 - accuracy: 0.8546 - val_loss: 0.5615 - val_accuracy: 0.8424
# Epoch 36/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.5368 - accuracy: 0.8589 - val_loss: 0.5745 - val_accuracy: 0.8450
# Epoch 37/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.5407 - accuracy: 0.8553 - val_loss: 0.5854 - val_accuracy: 0.8277
# Epoch 38/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.5287 - accuracy: 0.8615 - val_loss: 0.5677 - val_accuracy: 0.8441
# Epoch 39/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.5250 - accuracy: 0.8596 - val_loss: 0.5491 - val_accuracy: 0.8484
# Epoch 40/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.5252 - accuracy: 0.8557 - val_loss: 0.5587 - val_accuracy: 0.8493
# Epoch 41/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.5226 - accuracy: 0.8542 - val_loss: 0.5724 - val_accuracy: 0.8407
# Epoch 42/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.5222 - accuracy: 0.8613 - val_loss: 0.5813 - val_accuracy: 0.8329
# Epoch 43/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.5191 - accuracy: 0.8622 - val_loss: 0.5519 - val_accuracy: 0.8467
# Epoch 44/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.5196 - accuracy: 0.8604 - val_loss: 0.5533 - val_accuracy: 0.8493
# Epoch 45/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.5253 - accuracy: 0.8626 - val_loss: 0.5524 - val_accuracy: 0.8424
# Epoch 46/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.5044 - accuracy: 0.8684 - val_loss: 0.5436 - val_accuracy: 0.8484
# Epoch 47/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.5050 - accuracy: 0.8654 - val_loss: 0.5561 - val_accuracy: 0.8363
# Epoch 48/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.5030 - accuracy: 0.8661 - val_loss: 0.5495 - val_accuracy: 0.8475
# Epoch 49/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.5023 - accuracy: 0.8643 - val_loss: 0.5476 - val_accuracy: 0.8553
# Epoch 50/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.5043 - accuracy: 0.8652 - val_loss: 0.5688 - val_accuracy: 0.8441
# Epoch 51/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.4951 - accuracy: 0.8691 - val_loss: 0.5475 - val_accuracy: 0.8389
# Epoch 52/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.4946 - accuracy: 0.8697 - val_loss: 0.5644 - val_accuracy: 0.8458
# Epoch 53/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.4965 - accuracy: 0.8721 - val_loss: 0.5456 - val_accuracy: 0.8493
# Epoch 54/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.4925 - accuracy: 0.8712 - val_loss: 0.5514 - val_accuracy: 0.8562
# Epoch 55/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.4804 - accuracy: 0.8738 - val_loss: 0.5554 - val_accuracy: 0.8544
# Epoch 56/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.4921 - accuracy: 0.8687 - val_loss: 0.5460 - val_accuracy: 0.8536
# Epoch 57/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.4840 - accuracy: 0.8747 - val_loss: 0.5736 - val_accuracy: 0.8467
# Epoch 58/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.4845 - accuracy: 0.8745 - val_loss: 0.5706 - val_accuracy: 0.8579
# Epoch 59/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.4723 - accuracy: 0.8814 - val_loss: 0.5752 - val_accuracy: 0.8501
# Epoch 60/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.4806 - accuracy: 0.8747 - val_loss: 0.5382 - val_accuracy: 0.8579
# Epoch 61/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.4757 - accuracy: 0.8754 - val_loss: 0.5431 - val_accuracy: 0.8587
# Epoch 62/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.4757 - accuracy: 0.8771 - val_loss: 0.5545 - val_accuracy: 0.8544
# Epoch 63/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.4676 - accuracy: 0.8786 - val_loss: 0.5543 - val_accuracy: 0.8519
# Epoch 64/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.4673 - accuracy: 0.8805 - val_loss: 0.5506 - val_accuracy: 0.8458
# Epoch 65/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.4696 - accuracy: 0.8792 - val_loss: 0.5525 - val_accuracy: 0.8458
# Epoch 66/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.4604 - accuracy: 0.8805 - val_loss: 0.5467 - val_accuracy: 0.8665
# Epoch 67/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.4649 - accuracy: 0.8864 - val_loss: 0.5567 - val_accuracy: 0.8562
# Epoch 68/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.4634 - accuracy: 0.8859 - val_loss: 0.5407 - val_accuracy: 0.8519
# Epoch 69/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.4559 - accuracy: 0.8805 - val_loss: 0.5375 - val_accuracy: 0.8519
# Epoch 70/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.4737 - accuracy: 0.8782 - val_loss: 0.5555 - val_accuracy: 0.8544
# Epoch 71/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.4646 - accuracy: 0.8801 - val_loss: 0.5396 - val_accuracy: 0.8605
# Epoch 72/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.4575 - accuracy: 0.8799 - val_loss: 0.5539 - val_accuracy: 0.8493
# Epoch 73/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.4595 - accuracy: 0.8790 - val_loss: 0.5498 - val_accuracy: 0.8527
# Epoch 74/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.4572 - accuracy: 0.8836 - val_loss: 0.5666 - val_accuracy: 0.8501
# Epoch 75/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.4530 - accuracy: 0.8866 - val_loss: 0.5323 - val_accuracy: 0.8562
# Epoch 76/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.4565 - accuracy: 0.8844 - val_loss: 0.5481 - val_accuracy: 0.8562
# Epoch 77/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.4508 - accuracy: 0.8879 - val_loss: 0.5571 - val_accuracy: 0.8622
# Epoch 78/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.4485 - accuracy: 0.8849 - val_loss: 0.5456 - val_accuracy: 0.8613
# Epoch 79/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.4450 - accuracy: 0.8846 - val_loss: 0.5648 - val_accuracy: 0.8458
# Epoch 80/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.4505 - accuracy: 0.8797 - val_loss: 0.5400 - val_accuracy: 0.8570
# Epoch 81/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.4500 - accuracy: 0.8883 - val_loss: 0.5503 - val_accuracy: 0.8579
# Epoch 82/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.4473 - accuracy: 0.8874 - val_loss: 0.5383 - val_accuracy: 0.8613
# Epoch 83/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.4451 - accuracy: 0.8911 - val_loss: 0.5415 - val_accuracy: 0.8579
# Epoch 84/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.4351 - accuracy: 0.8892 - val_loss: 0.5589 - val_accuracy: 0.8570
# Epoch 85/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.4359 - accuracy: 0.8890 - val_loss: 0.5482 - val_accuracy: 0.8665
# Epoch 86/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.4378 - accuracy: 0.8887 - val_loss: 0.5582 - val_accuracy: 0.8570
# Epoch 87/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.4493 - accuracy: 0.8862 - val_loss: 0.5595 - val_accuracy: 0.8544
# Epoch 88/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.4262 - accuracy: 0.8933 - val_loss: 0.5470 - val_accuracy: 0.8553
# Epoch 89/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.4336 - accuracy: 0.8881 - val_loss: 0.5562 - val_accuracy: 0.8544
# Epoch 90/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.4323 - accuracy: 0.8946 - val_loss: 0.5395 - val_accuracy: 0.8613
# Epoch 91/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.4304 - accuracy: 0.8922 - val_loss: 0.5428 - val_accuracy: 0.8570
# Epoch 92/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.4406 - accuracy: 0.8890 - val_loss: 0.5385 - val_accuracy: 0.8613
# Epoch 93/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.4388 - accuracy: 0.8883 - val_loss: 0.5575 - val_accuracy: 0.8622
# Epoch 94/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.4327 - accuracy: 0.8892 - val_loss: 0.5469 - val_accuracy: 0.8501
# Epoch 95/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.4290 - accuracy: 0.8946 - val_loss: 0.5621 - val_accuracy: 0.8536
# Epoch 96/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.4302 - accuracy: 0.8918 - val_loss: 0.5510 - val_accuracy: 0.8579
# Epoch 97/200
# 73/73 [==============================] - 1s 12ms/step - loss: 0.4197 - accuracy: 0.8963 - val_loss: 0.5579 - val_accuracy: 0.8622
# Epoch 98/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.4251 - accuracy: 0.8900 - val_loss: 0.5635 - val_accuracy: 0.8570
# Epoch 99/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.4287 - accuracy: 0.8926 - val_loss: 0.5591 - val_accuracy: 0.8562
# Epoch 100/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.4215 - accuracy: 0.8950 - val_loss: 0.5788 - val_accuracy: 0.8536
# Epoch 101/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.4211 - accuracy: 0.9006 - val_loss: 0.5645 - val_accuracy: 0.8536
# Epoch 102/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.4256 - accuracy: 0.8909 - val_loss: 0.5656 - val_accuracy: 0.8484
# Epoch 103/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.4085 - accuracy: 0.8985 - val_loss: 0.5640 - val_accuracy: 0.8579
# Epoch 104/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.4146 - accuracy: 0.8963 - val_loss: 0.5674 - val_accuracy: 0.8536
# Epoch 105/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.4203 - accuracy: 0.8959 - val_loss: 0.5714 - val_accuracy: 0.8579
# Epoch 106/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.4144 - accuracy: 0.8974 - val_loss: 0.5727 - val_accuracy: 0.8622
# Epoch 107/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.4258 - accuracy: 0.8926 - val_loss: 0.5768 - val_accuracy: 0.8484
# Epoch 108/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.4134 - accuracy: 0.8950 - val_loss: 0.5704 - val_accuracy: 0.8579
# Epoch 109/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.4074 - accuracy: 0.8963 - val_loss: 0.5610 - val_accuracy: 0.8613
# Epoch 110/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.4126 - accuracy: 0.8974 - val_loss: 0.5682 - val_accuracy: 0.8484
# Epoch 111/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.4079 - accuracy: 0.8983 - val_loss: 0.5823 - val_accuracy: 0.8596
# Epoch 112/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.4069 - accuracy: 0.9021 - val_loss: 0.5609 - val_accuracy: 0.8536
# Epoch 113/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.4161 - accuracy: 0.8920 - val_loss: 0.6069 - val_accuracy: 0.8484
# Epoch 114/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.4132 - accuracy: 0.9052 - val_loss: 0.5690 - val_accuracy: 0.8605
# Epoch 115/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.4054 - accuracy: 0.9028 - val_loss: 0.5529 - val_accuracy: 0.8605
# Epoch 116/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.4073 - accuracy: 0.9006 - val_loss: 0.5648 - val_accuracy: 0.8484
# Epoch 117/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.4088 - accuracy: 0.9019 - val_loss: 0.5527 - val_accuracy: 0.8587
# Epoch 118/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.4013 - accuracy: 0.9015 - val_loss: 0.5649 - val_accuracy: 0.8510
# Epoch 119/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.3984 - accuracy: 0.9011 - val_loss: 0.5642 - val_accuracy: 0.8562
# Epoch 120/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.4051 - accuracy: 0.9034 - val_loss: 0.5734 - val_accuracy: 0.8562
# Epoch 121/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.4006 - accuracy: 0.9041 - val_loss: 0.5902 - val_accuracy: 0.8493
# Epoch 122/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.3990 - accuracy: 0.9004 - val_loss: 0.5532 - val_accuracy: 0.8579
# Epoch 123/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.4010 - accuracy: 0.9034 - val_loss: 0.5584 - val_accuracy: 0.8605
# Epoch 124/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.4039 - accuracy: 0.9017 - val_loss: 0.5949 - val_accuracy: 0.8519
# Epoch 125/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3920 - accuracy: 0.9067 - val_loss: 0.5499 - val_accuracy: 0.8553
# Epoch 126/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.4029 - accuracy: 0.8998 - val_loss: 0.5766 - val_accuracy: 0.8501
# Epoch 127/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.4042 - accuracy: 0.9019 - val_loss: 0.5691 - val_accuracy: 0.8536
# Epoch 128/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3961 - accuracy: 0.9028 - val_loss: 0.5835 - val_accuracy: 0.8544
# Epoch 129/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.3845 - accuracy: 0.9080 - val_loss: 0.5597 - val_accuracy: 0.8544
# Epoch 130/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3909 - accuracy: 0.9084 - val_loss: 0.5732 - val_accuracy: 0.8553
# Epoch 131/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.4038 - accuracy: 0.9028 - val_loss: 0.5737 - val_accuracy: 0.8596
# Epoch 132/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.4067 - accuracy: 0.9028 - val_loss: 0.5533 - val_accuracy: 0.8544
# Epoch 133/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3896 - accuracy: 0.9073 - val_loss: 0.5822 - val_accuracy: 0.8510
# Epoch 134/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.3980 - accuracy: 0.9058 - val_loss: 0.5784 - val_accuracy: 0.8587
# Epoch 135/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.3969 - accuracy: 0.9052 - val_loss: 0.5626 - val_accuracy: 0.8553
# Epoch 136/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.3922 - accuracy: 0.9041 - val_loss: 0.5849 - val_accuracy: 0.8570
# Epoch 137/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3884 - accuracy: 0.9125 - val_loss: 0.5645 - val_accuracy: 0.8570
# Epoch 138/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.4003 - accuracy: 0.9041 - val_loss: 0.5919 - val_accuracy: 0.8544
# Epoch 139/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3957 - accuracy: 0.9071 - val_loss: 0.5788 - val_accuracy: 0.8519
# Epoch 140/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3814 - accuracy: 0.9073 - val_loss: 0.5847 - val_accuracy: 0.8519
# Epoch 141/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3887 - accuracy: 0.9043 - val_loss: 0.5791 - val_accuracy: 0.8519
# Epoch 142/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3790 - accuracy: 0.9093 - val_loss: 0.5691 - val_accuracy: 0.8536
# Epoch 143/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3851 - accuracy: 0.9119 - val_loss: 0.5695 - val_accuracy: 0.8579
# Epoch 144/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.3871 - accuracy: 0.9058 - val_loss: 0.5643 - val_accuracy: 0.8639
# Epoch 145/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.3899 - accuracy: 0.9052 - val_loss: 0.5745 - val_accuracy: 0.8579
# Epoch 146/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3842 - accuracy: 0.9097 - val_loss: 0.5607 - val_accuracy: 0.8596
# Epoch 147/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.3886 - accuracy: 0.9108 - val_loss: 0.5748 - val_accuracy: 0.8665
# Epoch 148/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.3843 - accuracy: 0.9032 - val_loss: 0.5693 - val_accuracy: 0.8544
# Epoch 149/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3830 - accuracy: 0.9078 - val_loss: 0.5592 - val_accuracy: 0.8622
# Epoch 150/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.3871 - accuracy: 0.9080 - val_loss: 0.5695 - val_accuracy: 0.8553
# Epoch 151/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.3883 - accuracy: 0.9084 - val_loss: 0.5716 - val_accuracy: 0.8536
# Epoch 152/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3815 - accuracy: 0.9065 - val_loss: 0.5709 - val_accuracy: 0.8622
# Epoch 153/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.3768 - accuracy: 0.9062 - val_loss: 0.6081 - val_accuracy: 0.8475
# Epoch 154/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3786 - accuracy: 0.9086 - val_loss: 0.5967 - val_accuracy: 0.8519
# Epoch 155/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.3737 - accuracy: 0.9110 - val_loss: 0.6020 - val_accuracy: 0.8536
# Epoch 156/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3873 - accuracy: 0.9071 - val_loss: 0.5717 - val_accuracy: 0.8570
# Epoch 157/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3742 - accuracy: 0.9093 - val_loss: 0.5918 - val_accuracy: 0.8587
# Epoch 158/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3776 - accuracy: 0.9112 - val_loss: 0.5675 - val_accuracy: 0.8544
# Epoch 159/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.3802 - accuracy: 0.9114 - val_loss: 0.5807 - val_accuracy: 0.8630
# Epoch 160/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3765 - accuracy: 0.9101 - val_loss: 0.5896 - val_accuracy: 0.8527
# Epoch 161/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3768 - accuracy: 0.9157 - val_loss: 0.5937 - val_accuracy: 0.8544
# Epoch 162/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3761 - accuracy: 0.9080 - val_loss: 0.5963 - val_accuracy: 0.8527
# Epoch 163/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.3757 - accuracy: 0.9132 - val_loss: 0.5627 - val_accuracy: 0.8613
# Epoch 164/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.3783 - accuracy: 0.9112 - val_loss: 0.6001 - val_accuracy: 0.8570
# Epoch 165/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.3819 - accuracy: 0.9043 - val_loss: 0.5998 - val_accuracy: 0.8519
# Epoch 166/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3738 - accuracy: 0.9108 - val_loss: 0.5839 - val_accuracy: 0.8596
# Epoch 167/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.3703 - accuracy: 0.9099 - val_loss: 0.5694 - val_accuracy: 0.8570
# Epoch 168/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3760 - accuracy: 0.9116 - val_loss: 0.6012 - val_accuracy: 0.8493
# Epoch 169/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3735 - accuracy: 0.9142 - val_loss: 0.5961 - val_accuracy: 0.8553
# Epoch 170/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3770 - accuracy: 0.9097 - val_loss: 0.5920 - val_accuracy: 0.8562
# Epoch 171/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3742 - accuracy: 0.9106 - val_loss: 0.6231 - val_accuracy: 0.8562
# Epoch 172/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3827 - accuracy: 0.9034 - val_loss: 0.5701 - val_accuracy: 0.8605
# Epoch 173/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3680 - accuracy: 0.9147 - val_loss: 0.6068 - val_accuracy: 0.8562
# Epoch 174/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3742 - accuracy: 0.9106 - val_loss: 0.6061 - val_accuracy: 0.8544
# Epoch 175/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.3702 - accuracy: 0.9119 - val_loss: 0.5621 - val_accuracy: 0.8605
# Epoch 176/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3640 - accuracy: 0.9132 - val_loss: 0.5830 - val_accuracy: 0.8579
# Epoch 177/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.3644 - accuracy: 0.9145 - val_loss: 0.5726 - val_accuracy: 0.8630
# Epoch 178/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3634 - accuracy: 0.9149 - val_loss: 0.5577 - val_accuracy: 0.8579
# Epoch 179/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3634 - accuracy: 0.9136 - val_loss: 0.5788 - val_accuracy: 0.8630
# Epoch 180/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.3684 - accuracy: 0.9149 - val_loss: 0.5678 - val_accuracy: 0.8570
# Epoch 181/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.3687 - accuracy: 0.9116 - val_loss: 0.6233 - val_accuracy: 0.8467
# Epoch 182/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.3666 - accuracy: 0.9103 - val_loss: 0.6048 - val_accuracy: 0.8613
# Epoch 183/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3737 - accuracy: 0.9134 - val_loss: 0.5987 - val_accuracy: 0.8562
# Epoch 184/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.3689 - accuracy: 0.9140 - val_loss: 0.5938 - val_accuracy: 0.8544
# Epoch 185/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.3716 - accuracy: 0.9142 - val_loss: 0.5953 - val_accuracy: 0.8562
# Epoch 186/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3708 - accuracy: 0.9132 - val_loss: 0.6092 - val_accuracy: 0.8493
# Epoch 187/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3717 - accuracy: 0.9129 - val_loss: 0.5772 - val_accuracy: 0.8596
# Epoch 188/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.3540 - accuracy: 0.9166 - val_loss: 0.5905 - val_accuracy: 0.8587
# Epoch 189/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.3573 - accuracy: 0.9140 - val_loss: 0.6287 - val_accuracy: 0.8493
# Epoch 190/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.3637 - accuracy: 0.9132 - val_loss: 0.5836 - val_accuracy: 0.8605
# Epoch 191/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3633 - accuracy: 0.9166 - val_loss: 0.5992 - val_accuracy: 0.8622
# Epoch 192/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3700 - accuracy: 0.9123 - val_loss: 0.6045 - val_accuracy: 0.8613
# Epoch 193/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3577 - accuracy: 0.9199 - val_loss: 0.5950 - val_accuracy: 0.8596
# Epoch 194/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.3484 - accuracy: 0.9199 - val_loss: 0.5969 - val_accuracy: 0.8587
# Epoch 195/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3607 - accuracy: 0.9145 - val_loss: 0.5884 - val_accuracy: 0.8536
# Epoch 196/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3706 - accuracy: 0.9140 - val_loss: 0.5872 - val_accuracy: 0.8630
# Epoch 197/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3670 - accuracy: 0.9119 - val_loss: 0.5839 - val_accuracy: 0.8579
# Epoch 198/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3606 - accuracy: 0.9162 - val_loss: 0.5891 - val_accuracy: 0.8587
# Epoch 199/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3636 - accuracy: 0.9127 - val_loss: 0.6291 - val_accuracy: 0.8501
# Epoch 200/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3770 - accuracy: 0.9095 - val_loss: 0.5892 - val_accuracy: 0.8639

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
loss, accuracy = model.evaluate(test)
print('Test accuracy :', accuracy)
# Out:
# 19/19 [==============================] - 0s 7ms/step - loss: 0.5892 - accuracy: 0.8639
# Test accuracy : 0.863910436630249

# %%
# Save the entire model as a SavedModel.
# model.save('./data/humanModel/mode_v0')
model.save('./data/'+map_dir+'/humanModel_v0.h5')

# %%
# save model in js format
# import tensorflowjs as tfjs
# tfjs.converters.save_keras_model(model, 'data/humanModel/js_model_v0')

# %%
# new_model = tf.keras.models.load_model('./data/humanModel/mode_v0')

# # Check its architecture
# new_model.summary()

# %% [markdown]
# ### Predict on new data

# %%
path = "./data/humanModel_v0_dataset_split/val/38/-Mr4e3Fomo72jz0zfTgB_14.png"

img = keras.preprocessing.image.load_img(
    path, target_size=(IMG_SIZE, IMG_SIZE)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch
img_array = img_array/255
predictions = model.predict(img_array)[0]

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(np.argmax(predictions), 100 * np.max(predictions))
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_52855/306757993.py in <module>
#       2
#       3 img = keras.preprocessing.image.load_img(
# ----> 4     path, target_size=(IMG_SIZE, IMG_SIZE)
#       5 )
#       6 img_array = keras.preprocessing.image.img_to_array(img)
#
# ~/anaconda3/envs/tf-gpu/lib/python3.7/site-packages/keras/preprocessing/image.py in load_img(path, grayscale, color_mode, target_size, interpolation)
#     312   """
#     313   return image.load_img(path, grayscale=grayscale, color_mode=color_mode,
# --> 314                         target_size=target_size, interpolation=interpolation)
#     315
#     316
#
# ~/anaconda3/envs/tf-gpu/lib/python3.7/site-packages/keras_preprocessing/image/utils.py in load_img(path, grayscale, color_mode, target_size, interpolation)
#     111         raise ImportError('Could not import PIL.Image. '
#     112                           'The use of `load_img` requires PIL.')
# --> 113     with open(path, 'rb') as f:
#     114         img = pil_image.open(io.BytesIO(f.read()))
#     115         if color_mode == 'grayscale':
#
# FileNotFoundError: [Errno 2] No such file or directory: './data/humanModel_v0_dataset_split/val/38/-Mr4e3Fomo72jz0zfTgB_14.png'
