# %%
import numpy as np
import random
import os
import shutil

# ! pip install split-folders
import splitfolders

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, regularizers
from tensorflow.keras.models import Sequential

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image

import matplotlib.pyplot as plt

rs = 42
def reset_random_seeds(rs):
   os.environ['PYTHONHASHSEED']=str(rs)
   tf.random.set_seed(rs)
   np.random.seed(rs)
   random.seed(rs)
reset_random_seeds(rs)

map_dir = 'map 5'

# %% [markdown]
# remove prev saved database:

# %%
dir_path = './data/humanModel_v0_dataset_split'
if os.path.exists(dir_path):
    shutil.rmtree(dir_path)
else:
    print("File not found in the directory")
# Out:
# File not found in the directory

# %% [markdown]
# # Part 1 - Data Preprocessing

# %% [markdown]
# ## Split into train , test data

# %%
# train, test split
splitfolders.ratio('./data/humanModel_v0_dataset/', output="./data/humanModel_v0_dataset_split", ratio=(0.8, 0.2))
# Out:
# Copying files: 5790 files [00:00, 17488.51 files/s]

# %% [markdown]
# ### Preprocessing the Training set

# %%
batch_size = 64
IMG_SIZE = 10

datagen = ImageDataGenerator(rescale = 1./255)
train = datagen.flow_from_directory('./data/humanModel_v0_dataset_split/train',
                                          target_size = (IMG_SIZE,IMG_SIZE), batch_size = batch_size, seed=rs, class_mode='sparse')

test = datagen.flow_from_directory('./data/humanModel_v0_dataset_split/val',
                                            target_size = (IMG_SIZE, IMG_SIZE), batch_size = batch_size, seed=rs, class_mode='sparse')
# Out:
# Found 4629 images belonging to 5 classes.
# Found 1161 images belonging to 5 classes.

# %% [markdown]
# ## View some data

# %%
num_classes = 5

model = Sequential([
  layers.Conv2D(8, 4, padding='same', activation='relu', kernel_regularizer=regularizers.l2(0.001), input_shape=[IMG_SIZE,IMG_SIZE,3]),
  layers.Conv2D(16, 4, padding='same', activation='relu', kernel_regularizer=regularizers.l2(0.001)),
  layers.Conv2D(16, 3, padding='same', activation='relu', kernel_regularizer=regularizers.l2(0.001)),
  layers.MaxPooling2D(),
  layers.Conv2D(8, 3, padding='same', activation='relu', kernel_regularizer=regularizers.l2(0.001)),
  layers.Dropout(0.5),
  layers.Flatten(),
  layers.Dense(32, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
  layers.Dense(num_classes, activation='softmax')
])
# Out:
# 2022-05-11 17:57:08.945495: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-11 17:57:08.950583: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-11 17:57:08.950888: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-11 17:57:08.951819: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-05-11 17:57:08.952242: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-11 17:57:08.952534: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-11 17:57:08.952801: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-11 17:57:09.270837: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-11 17:57:09.271176: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-11 17:57:09.271450: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-11 17:57:09.271712: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 11208 MB memory:  -> device: 0, name: NVIDIA TITAN X (Pascal), pci bus id: 0000:01:00.0, compute capability: 6.1

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 10, 10, 8)         392
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 10, 10, 16)        2064
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 10, 10, 16)        2320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 5, 5, 16)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 5, 5, 8)           1160
# _________________________________________________________________
# dropout (Dropout)            (None, 5, 5, 8)           0
# _________________________________________________________________
# flatten (Flatten)            (None, 200)               0
# _________________________________________________________________
# dense (Dense)                (None, 32)                6432
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 165
# =================================================================
# Total params: 12,533
# Trainable params: 12,533
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs=200
history = model.fit(
  train,
  validation_data=test,
  epochs=epochs
)
# Out:
# Epoch 1/200
# 2022-05-11 17:57:09.645769: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# /home/ido/anaconda3/envs/tf-gpu/lib/python3.7/site-packages/keras/backend.py:4907: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   '"`sparse_categorical_crossentropy` received `from_logits=True`, but '
# 2022-05-11 17:57:10.203215: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8100
# 2022-05-11 17:57:10.360041: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 73/73 [==============================] - 2s 11ms/step - loss: 1.5598 - accuracy: 0.3640 - val_loss: 1.4537 - val_accuracy: 0.3738
# Epoch 2/200
# 73/73 [==============================] - 1s 9ms/step - loss: 1.3622 - accuracy: 0.4383 - val_loss: 1.1869 - val_accuracy: 0.5177
# Epoch 3/200
# 73/73 [==============================] - 1s 9ms/step - loss: 1.1625 - accuracy: 0.5701 - val_loss: 1.0415 - val_accuracy: 0.6736
# Epoch 4/200
# 73/73 [==============================] - 1s 9ms/step - loss: 1.0072 - accuracy: 0.6572 - val_loss: 0.8864 - val_accuracy: 0.7183
# Epoch 5/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.9129 - accuracy: 0.6958 - val_loss: 0.8135 - val_accuracy: 0.7235
# Epoch 6/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.8568 - accuracy: 0.7261 - val_loss: 0.7653 - val_accuracy: 0.7347
# Epoch 7/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.8093 - accuracy: 0.7339 - val_loss: 0.7380 - val_accuracy: 0.7494
# Epoch 8/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.7812 - accuracy: 0.7593 - val_loss: 0.7157 - val_accuracy: 0.7778
# Epoch 9/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.7771 - accuracy: 0.7593 - val_loss: 0.6995 - val_accuracy: 0.7795
# Epoch 10/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.7456 - accuracy: 0.7714 - val_loss: 0.7083 - val_accuracy: 0.7778
# Epoch 11/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.7180 - accuracy: 0.7820 - val_loss: 0.6837 - val_accuracy: 0.7735
# Epoch 12/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.7053 - accuracy: 0.7874 - val_loss: 0.6595 - val_accuracy: 0.8088
# Epoch 13/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.6895 - accuracy: 0.7937 - val_loss: 0.6553 - val_accuracy: 0.8148
# Epoch 14/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.6842 - accuracy: 0.7928 - val_loss: 0.6608 - val_accuracy: 0.7967
# Epoch 15/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.6851 - accuracy: 0.8025 - val_loss: 0.6325 - val_accuracy: 0.8252
# Epoch 16/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.6715 - accuracy: 0.8045 - val_loss: 0.6427 - val_accuracy: 0.8053
# Epoch 17/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.6586 - accuracy: 0.8101 - val_loss: 0.6362 - val_accuracy: 0.8105
# Epoch 18/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.6401 - accuracy: 0.8166 - val_loss: 0.6303 - val_accuracy: 0.8252
# Epoch 19/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.6393 - accuracy: 0.8138 - val_loss: 0.6249 - val_accuracy: 0.8105
# Epoch 20/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.6196 - accuracy: 0.8233 - val_loss: 0.6054 - val_accuracy: 0.8320
# Epoch 21/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.6222 - accuracy: 0.8252 - val_loss: 0.6468 - val_accuracy: 0.8079
# Epoch 22/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.6096 - accuracy: 0.8280 - val_loss: 0.6001 - val_accuracy: 0.8312
# Epoch 23/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.6040 - accuracy: 0.8302 - val_loss: 0.5965 - val_accuracy: 0.8096
# Epoch 24/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.5963 - accuracy: 0.8246 - val_loss: 0.5838 - val_accuracy: 0.8372
# Epoch 25/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.5888 - accuracy: 0.8395 - val_loss: 0.5954 - val_accuracy: 0.8260
# Epoch 26/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.5885 - accuracy: 0.8319 - val_loss: 0.5797 - val_accuracy: 0.8295
# Epoch 27/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.5696 - accuracy: 0.8429 - val_loss: 0.5799 - val_accuracy: 0.8355
# Epoch 28/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.5672 - accuracy: 0.8445 - val_loss: 0.5898 - val_accuracy: 0.8338
# Epoch 29/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.5660 - accuracy: 0.8419 - val_loss: 0.5659 - val_accuracy: 0.8441
# Epoch 30/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.5569 - accuracy: 0.8496 - val_loss: 0.5784 - val_accuracy: 0.8303
# Epoch 31/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.5537 - accuracy: 0.8512 - val_loss: 0.5672 - val_accuracy: 0.8407
# Epoch 32/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.5568 - accuracy: 0.8445 - val_loss: 0.5763 - val_accuracy: 0.8320
# Epoch 33/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.5516 - accuracy: 0.8525 - val_loss: 0.5694 - val_accuracy: 0.8346
# Epoch 34/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.5456 - accuracy: 0.8449 - val_loss: 0.5781 - val_accuracy: 0.8398
# Epoch 35/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.5446 - accuracy: 0.8473 - val_loss: 0.5648 - val_accuracy: 0.8424
# Epoch 36/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.5409 - accuracy: 0.8492 - val_loss: 0.5636 - val_accuracy: 0.8467
# Epoch 37/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.5412 - accuracy: 0.8466 - val_loss: 0.5698 - val_accuracy: 0.8415
# Epoch 38/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.5321 - accuracy: 0.8542 - val_loss: 0.5589 - val_accuracy: 0.8389
# Epoch 39/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.5252 - accuracy: 0.8561 - val_loss: 0.6051 - val_accuracy: 0.8372
# Epoch 40/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.5235 - accuracy: 0.8561 - val_loss: 0.5587 - val_accuracy: 0.8510
# Epoch 41/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.5087 - accuracy: 0.8658 - val_loss: 0.5824 - val_accuracy: 0.8355
# Epoch 42/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.5162 - accuracy: 0.8600 - val_loss: 0.5795 - val_accuracy: 0.8303
# Epoch 43/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.5130 - accuracy: 0.8583 - val_loss: 0.5607 - val_accuracy: 0.8501
# Epoch 44/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.5144 - accuracy: 0.8611 - val_loss: 0.5660 - val_accuracy: 0.8269
# Epoch 45/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.5114 - accuracy: 0.8600 - val_loss: 0.5512 - val_accuracy: 0.8415
# Epoch 46/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.5113 - accuracy: 0.8667 - val_loss: 0.5471 - val_accuracy: 0.8519
# Epoch 47/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.5163 - accuracy: 0.8620 - val_loss: 0.5570 - val_accuracy: 0.8570
# Epoch 48/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.5010 - accuracy: 0.8663 - val_loss: 0.5471 - val_accuracy: 0.8407
# Epoch 49/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.4988 - accuracy: 0.8674 - val_loss: 0.5490 - val_accuracy: 0.8432
# Epoch 50/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.4956 - accuracy: 0.8704 - val_loss: 0.5428 - val_accuracy: 0.8484
# Epoch 51/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.4911 - accuracy: 0.8691 - val_loss: 0.5546 - val_accuracy: 0.8536
# Epoch 52/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.5012 - accuracy: 0.8624 - val_loss: 0.5458 - val_accuracy: 0.8501
# Epoch 53/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.4966 - accuracy: 0.8682 - val_loss: 0.5496 - val_accuracy: 0.8519
# Epoch 54/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.4957 - accuracy: 0.8730 - val_loss: 0.5568 - val_accuracy: 0.8493
# Epoch 55/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.4762 - accuracy: 0.8736 - val_loss: 0.5775 - val_accuracy: 0.8475
# Epoch 56/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.4886 - accuracy: 0.8684 - val_loss: 0.5459 - val_accuracy: 0.8484
# Epoch 57/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.4817 - accuracy: 0.8708 - val_loss: 0.5576 - val_accuracy: 0.8536
# Epoch 58/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.4679 - accuracy: 0.8797 - val_loss: 0.5496 - val_accuracy: 0.8407
# Epoch 59/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.4776 - accuracy: 0.8799 - val_loss: 0.5526 - val_accuracy: 0.8458
# Epoch 60/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.4781 - accuracy: 0.8745 - val_loss: 0.5468 - val_accuracy: 0.8605
# Epoch 61/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.4711 - accuracy: 0.8775 - val_loss: 0.5444 - val_accuracy: 0.8484
# Epoch 62/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.4706 - accuracy: 0.8790 - val_loss: 0.5423 - val_accuracy: 0.8553
# Epoch 63/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.4683 - accuracy: 0.8786 - val_loss: 0.5797 - val_accuracy: 0.8536
# Epoch 64/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.4641 - accuracy: 0.8784 - val_loss: 0.5493 - val_accuracy: 0.8510
# Epoch 65/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.4793 - accuracy: 0.8732 - val_loss: 0.5500 - val_accuracy: 0.8562
# Epoch 66/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.4681 - accuracy: 0.8773 - val_loss: 0.5549 - val_accuracy: 0.8562
# Epoch 67/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.4642 - accuracy: 0.8827 - val_loss: 0.5524 - val_accuracy: 0.8553
# Epoch 68/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.4658 - accuracy: 0.8784 - val_loss: 0.5488 - val_accuracy: 0.8424
# Epoch 69/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.4573 - accuracy: 0.8801 - val_loss: 0.5522 - val_accuracy: 0.8527
# Epoch 70/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.4606 - accuracy: 0.8790 - val_loss: 0.5453 - val_accuracy: 0.8570
# Epoch 71/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.4551 - accuracy: 0.8803 - val_loss: 0.5579 - val_accuracy: 0.8467
# Epoch 72/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.4677 - accuracy: 0.8786 - val_loss: 0.5525 - val_accuracy: 0.8493
# Epoch 73/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.4564 - accuracy: 0.8795 - val_loss: 0.5487 - val_accuracy: 0.8501
# Epoch 74/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.4569 - accuracy: 0.8855 - val_loss: 0.5898 - val_accuracy: 0.8458
# Epoch 75/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.4478 - accuracy: 0.8797 - val_loss: 0.5432 - val_accuracy: 0.8579
# Epoch 76/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.4509 - accuracy: 0.8877 - val_loss: 0.5635 - val_accuracy: 0.8519
# Epoch 77/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.4570 - accuracy: 0.8808 - val_loss: 0.5380 - val_accuracy: 0.8605
# Epoch 78/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.4531 - accuracy: 0.8877 - val_loss: 0.5426 - val_accuracy: 0.8570
# Epoch 79/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.4436 - accuracy: 0.8836 - val_loss: 0.5519 - val_accuracy: 0.8519
# Epoch 80/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.4386 - accuracy: 0.8827 - val_loss: 0.5495 - val_accuracy: 0.8510
# Epoch 81/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.4376 - accuracy: 0.8911 - val_loss: 0.5438 - val_accuracy: 0.8553
# Epoch 82/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.4349 - accuracy: 0.8874 - val_loss: 0.5287 - val_accuracy: 0.8562
# Epoch 83/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.4432 - accuracy: 0.8866 - val_loss: 0.5548 - val_accuracy: 0.8596
# Epoch 84/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.4426 - accuracy: 0.8874 - val_loss: 0.5541 - val_accuracy: 0.8562
# Epoch 85/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.4323 - accuracy: 0.8887 - val_loss: 0.5377 - val_accuracy: 0.8579
# Epoch 86/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.4303 - accuracy: 0.8883 - val_loss: 0.5437 - val_accuracy: 0.8587
# Epoch 87/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.4294 - accuracy: 0.8855 - val_loss: 0.5450 - val_accuracy: 0.8519
# Epoch 88/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.4331 - accuracy: 0.8879 - val_loss: 0.5475 - val_accuracy: 0.8570
# Epoch 89/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.4276 - accuracy: 0.8928 - val_loss: 0.5488 - val_accuracy: 0.8622
# Epoch 90/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.4172 - accuracy: 0.8952 - val_loss: 0.5592 - val_accuracy: 0.8536
# Epoch 91/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.4187 - accuracy: 0.8989 - val_loss: 0.5563 - val_accuracy: 0.8605
# Epoch 92/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.4237 - accuracy: 0.8909 - val_loss: 0.5500 - val_accuracy: 0.8648
# Epoch 93/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.4245 - accuracy: 0.8931 - val_loss: 0.5516 - val_accuracy: 0.8484
# Epoch 94/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.4216 - accuracy: 0.8950 - val_loss: 0.5630 - val_accuracy: 0.8527
# Epoch 95/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.4194 - accuracy: 0.8978 - val_loss: 0.5610 - val_accuracy: 0.8501
# Epoch 96/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.4202 - accuracy: 0.8898 - val_loss: 0.5519 - val_accuracy: 0.8622
# Epoch 97/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.4128 - accuracy: 0.9034 - val_loss: 0.5433 - val_accuracy: 0.8544
# Epoch 98/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.4122 - accuracy: 0.9043 - val_loss: 0.5777 - val_accuracy: 0.8544
# Epoch 99/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.4212 - accuracy: 0.8928 - val_loss: 0.5371 - val_accuracy: 0.8665
# Epoch 100/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.4201 - accuracy: 0.8965 - val_loss: 0.5513 - val_accuracy: 0.8579
# Epoch 101/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.4088 - accuracy: 0.8970 - val_loss: 0.5594 - val_accuracy: 0.8562
# Epoch 102/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.4222 - accuracy: 0.8928 - val_loss: 0.5424 - val_accuracy: 0.8544
# Epoch 103/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.4066 - accuracy: 0.8991 - val_loss: 0.5545 - val_accuracy: 0.8570
# Epoch 104/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.4146 - accuracy: 0.8967 - val_loss: 0.5526 - val_accuracy: 0.8570
# Epoch 105/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.4196 - accuracy: 0.8918 - val_loss: 0.5471 - val_accuracy: 0.8475
# Epoch 106/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.4100 - accuracy: 0.8976 - val_loss: 0.5685 - val_accuracy: 0.8579
# Epoch 107/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.4078 - accuracy: 0.8985 - val_loss: 0.5797 - val_accuracy: 0.8596
# Epoch 108/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3982 - accuracy: 0.9030 - val_loss: 0.5754 - val_accuracy: 0.8536
# Epoch 109/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.4011 - accuracy: 0.9015 - val_loss: 0.5603 - val_accuracy: 0.8587
# Epoch 110/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3979 - accuracy: 0.9011 - val_loss: 0.5613 - val_accuracy: 0.8562
# Epoch 111/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3950 - accuracy: 0.9065 - val_loss: 0.5873 - val_accuracy: 0.8501
# Epoch 112/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.4040 - accuracy: 0.8983 - val_loss: 0.5763 - val_accuracy: 0.8493
# Epoch 113/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3974 - accuracy: 0.9039 - val_loss: 0.5634 - val_accuracy: 0.8536
# Epoch 114/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3991 - accuracy: 0.9000 - val_loss: 0.5663 - val_accuracy: 0.8553
# Epoch 115/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.4057 - accuracy: 0.8959 - val_loss: 0.5611 - val_accuracy: 0.8493
# Epoch 116/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.4006 - accuracy: 0.8983 - val_loss: 0.5555 - val_accuracy: 0.8536
# Epoch 117/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.4048 - accuracy: 0.9019 - val_loss: 0.5547 - val_accuracy: 0.8605
# Epoch 118/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.4032 - accuracy: 0.8976 - val_loss: 0.5715 - val_accuracy: 0.8622
# Epoch 119/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3918 - accuracy: 0.9056 - val_loss: 0.5626 - val_accuracy: 0.8536
# Epoch 120/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3888 - accuracy: 0.9067 - val_loss: 0.5659 - val_accuracy: 0.8596
# Epoch 121/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3965 - accuracy: 0.9043 - val_loss: 0.5482 - val_accuracy: 0.8570
# Epoch 122/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3910 - accuracy: 0.9062 - val_loss: 0.5932 - val_accuracy: 0.8553
# Epoch 123/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.4010 - accuracy: 0.9019 - val_loss: 0.5739 - val_accuracy: 0.8493
# Epoch 124/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3939 - accuracy: 0.9045 - val_loss: 0.5596 - val_accuracy: 0.8587
# Epoch 125/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3857 - accuracy: 0.9017 - val_loss: 0.5512 - val_accuracy: 0.8527
# Epoch 126/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3909 - accuracy: 0.9054 - val_loss: 0.5729 - val_accuracy: 0.8622
# Epoch 127/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3894 - accuracy: 0.9071 - val_loss: 0.5596 - val_accuracy: 0.8570
# Epoch 128/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3822 - accuracy: 0.9086 - val_loss: 0.5501 - val_accuracy: 0.8656
# Epoch 129/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3800 - accuracy: 0.9119 - val_loss: 0.5689 - val_accuracy: 0.8648
# Epoch 130/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3843 - accuracy: 0.9088 - val_loss: 0.5483 - val_accuracy: 0.8622
# Epoch 131/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3775 - accuracy: 0.9140 - val_loss: 0.5834 - val_accuracy: 0.8587
# Epoch 132/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3845 - accuracy: 0.9088 - val_loss: 0.5589 - val_accuracy: 0.8596
# Epoch 133/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3770 - accuracy: 0.9093 - val_loss: 0.5610 - val_accuracy: 0.8587
# Epoch 134/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3882 - accuracy: 0.9052 - val_loss: 0.5554 - val_accuracy: 0.8596
# Epoch 135/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3861 - accuracy: 0.9034 - val_loss: 0.5658 - val_accuracy: 0.8630
# Epoch 136/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3806 - accuracy: 0.9125 - val_loss: 0.5877 - val_accuracy: 0.8553
# Epoch 137/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3790 - accuracy: 0.9116 - val_loss: 0.5651 - val_accuracy: 0.8467
# Epoch 138/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3867 - accuracy: 0.9052 - val_loss: 0.5895 - val_accuracy: 0.8553
# Epoch 139/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3855 - accuracy: 0.9054 - val_loss: 0.5638 - val_accuracy: 0.8553
# Epoch 140/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3865 - accuracy: 0.9041 - val_loss: 0.5593 - val_accuracy: 0.8622
# Epoch 141/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3865 - accuracy: 0.9071 - val_loss: 0.5647 - val_accuracy: 0.8587
# Epoch 142/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3801 - accuracy: 0.9088 - val_loss: 0.5660 - val_accuracy: 0.8570
# Epoch 143/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3745 - accuracy: 0.9101 - val_loss: 0.5776 - val_accuracy: 0.8596
# Epoch 144/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3608 - accuracy: 0.9132 - val_loss: 0.5677 - val_accuracy: 0.8544
# Epoch 145/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3777 - accuracy: 0.9071 - val_loss: 0.5488 - val_accuracy: 0.8691
# Epoch 146/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3783 - accuracy: 0.9080 - val_loss: 0.5524 - val_accuracy: 0.8562
# Epoch 147/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3792 - accuracy: 0.9119 - val_loss: 0.5727 - val_accuracy: 0.8587
# Epoch 148/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3743 - accuracy: 0.9110 - val_loss: 0.5702 - val_accuracy: 0.8475
# Epoch 149/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3725 - accuracy: 0.9110 - val_loss: 0.5960 - val_accuracy: 0.8544
# Epoch 150/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3700 - accuracy: 0.9123 - val_loss: 0.5681 - val_accuracy: 0.8674
# Epoch 151/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3692 - accuracy: 0.9140 - val_loss: 0.5601 - val_accuracy: 0.8562
# Epoch 152/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3658 - accuracy: 0.9129 - val_loss: 0.5955 - val_accuracy: 0.8441
# Epoch 153/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3811 - accuracy: 0.9073 - val_loss: 0.6002 - val_accuracy: 0.8553
# Epoch 154/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3623 - accuracy: 0.9173 - val_loss: 0.5650 - val_accuracy: 0.8596
# Epoch 155/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3715 - accuracy: 0.9121 - val_loss: 0.5726 - val_accuracy: 0.8622
# Epoch 156/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3670 - accuracy: 0.9129 - val_loss: 0.5838 - val_accuracy: 0.8613
# Epoch 157/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3658 - accuracy: 0.9149 - val_loss: 0.5740 - val_accuracy: 0.8536
# Epoch 158/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3641 - accuracy: 0.9125 - val_loss: 0.6039 - val_accuracy: 0.8570
# Epoch 159/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3628 - accuracy: 0.9138 - val_loss: 0.5968 - val_accuracy: 0.8484
# Epoch 160/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3707 - accuracy: 0.9086 - val_loss: 0.5723 - val_accuracy: 0.8553
# Epoch 161/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3635 - accuracy: 0.9142 - val_loss: 0.5774 - val_accuracy: 0.8587
# Epoch 162/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3650 - accuracy: 0.9110 - val_loss: 0.5897 - val_accuracy: 0.8544
# Epoch 163/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3617 - accuracy: 0.9149 - val_loss: 0.5741 - val_accuracy: 0.8596
# Epoch 164/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3600 - accuracy: 0.9153 - val_loss: 0.5970 - val_accuracy: 0.8579
# Epoch 165/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3692 - accuracy: 0.9151 - val_loss: 0.5980 - val_accuracy: 0.8553
# Epoch 166/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3592 - accuracy: 0.9123 - val_loss: 0.6263 - val_accuracy: 0.8355
# Epoch 167/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3607 - accuracy: 0.9170 - val_loss: 0.5871 - val_accuracy: 0.8544
# Epoch 168/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3611 - accuracy: 0.9166 - val_loss: 0.5912 - val_accuracy: 0.8630
# Epoch 169/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3641 - accuracy: 0.9129 - val_loss: 0.5687 - val_accuracy: 0.8596
# Epoch 170/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3614 - accuracy: 0.9190 - val_loss: 0.5784 - val_accuracy: 0.8622
# Epoch 171/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3590 - accuracy: 0.9134 - val_loss: 0.5871 - val_accuracy: 0.8630
# Epoch 172/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3548 - accuracy: 0.9157 - val_loss: 0.5951 - val_accuracy: 0.8613
# Epoch 173/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3488 - accuracy: 0.9151 - val_loss: 0.5878 - val_accuracy: 0.8562
# Epoch 174/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3559 - accuracy: 0.9170 - val_loss: 0.5992 - val_accuracy: 0.8562
# Epoch 175/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3557 - accuracy: 0.9173 - val_loss: 0.5972 - val_accuracy: 0.8467
# Epoch 176/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3514 - accuracy: 0.9205 - val_loss: 0.5781 - val_accuracy: 0.8562
# Epoch 177/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3698 - accuracy: 0.9110 - val_loss: 0.6142 - val_accuracy: 0.8544
# Epoch 178/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3546 - accuracy: 0.9149 - val_loss: 0.5667 - val_accuracy: 0.8579
# Epoch 179/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3581 - accuracy: 0.9127 - val_loss: 0.5756 - val_accuracy: 0.8553
# Epoch 180/200
# 73/73 [==============================] - 1s 10ms/step - loss: 0.3540 - accuracy: 0.9166 - val_loss: 0.5774 - val_accuracy: 0.8596
# Epoch 181/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3482 - accuracy: 0.9203 - val_loss: 0.6117 - val_accuracy: 0.8630
# Epoch 182/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3611 - accuracy: 0.9162 - val_loss: 0.6317 - val_accuracy: 0.8553
# Epoch 183/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3481 - accuracy: 0.9248 - val_loss: 0.5947 - val_accuracy: 0.8536
# Epoch 184/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3588 - accuracy: 0.9108 - val_loss: 0.5864 - val_accuracy: 0.8587
# Epoch 185/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3504 - accuracy: 0.9229 - val_loss: 0.6046 - val_accuracy: 0.8519
# Epoch 186/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3513 - accuracy: 0.9164 - val_loss: 0.5804 - val_accuracy: 0.8596
# Epoch 187/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3610 - accuracy: 0.9142 - val_loss: 0.5842 - val_accuracy: 0.8613
# Epoch 188/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3468 - accuracy: 0.9224 - val_loss: 0.6086 - val_accuracy: 0.8622
# Epoch 189/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3591 - accuracy: 0.9157 - val_loss: 0.5995 - val_accuracy: 0.8527
# Epoch 190/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3484 - accuracy: 0.9199 - val_loss: 0.5842 - val_accuracy: 0.8622
# Epoch 191/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3465 - accuracy: 0.9211 - val_loss: 0.6171 - val_accuracy: 0.8544
# Epoch 192/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3476 - accuracy: 0.9231 - val_loss: 0.6041 - val_accuracy: 0.8587
# Epoch 193/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3530 - accuracy: 0.9201 - val_loss: 0.6345 - val_accuracy: 0.8630
# Epoch 194/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3411 - accuracy: 0.9170 - val_loss: 0.6166 - val_accuracy: 0.8579
# Epoch 195/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3499 - accuracy: 0.9220 - val_loss: 0.5755 - val_accuracy: 0.8519
# Epoch 196/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3445 - accuracy: 0.9186 - val_loss: 0.5861 - val_accuracy: 0.8639
# Epoch 197/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3396 - accuracy: 0.9227 - val_loss: 0.5876 - val_accuracy: 0.8622
# Epoch 198/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3424 - accuracy: 0.9222 - val_loss: 0.5934 - val_accuracy: 0.8622
# Epoch 199/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3381 - accuracy: 0.9229 - val_loss: 0.6338 - val_accuracy: 0.8536
# Epoch 200/200
# 73/73 [==============================] - 1s 9ms/step - loss: 0.3420 - accuracy: 0.9222 - val_loss: 0.6314 - val_accuracy: 0.8613

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
loss, accuracy = model.evaluate(test)
print('Test accuracy :', accuracy)
# Out:
# 19/19 [==============================] - 0s 8ms/step - loss: 0.6314 - accuracy: 0.8613
# Test accuracy : 0.8613264560699463

# %%
# Save the entire model as a SavedModel.
# model.save('./data/humanModel/mode_v0')
model.save('./data/'+map_dir+'/humanModel_v0.h5')

# %%
# save model in js format
# import tensorflowjs as tfjs
# tfjs.converters.save_keras_model(model, 'data/humanModel/js_model_v0')

# %%
# new_model = tf.keras.models.load_model('./data/humanModel/mode_v0')

# # Check its architecture
# new_model.summary()

# %% [markdown]
# ### Predict on new data

# %%
path = "./data/humanModel_v0_dataset_split/val/38/-Mr4e3Fomo72jz0zfTgB_14.png"

img = keras.preprocessing.image.load_img(
    path, target_size=(IMG_SIZE, IMG_SIZE)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch
img_array = img_array/255
predictions = model.predict(img_array)[0]

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(np.argmax(predictions), 100 * np.max(predictions))
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_3116742/1618442636.py in <module>
#       2
#       3 img = keras.preprocessing.image.load_img(
# ----> 4     path, target_size=(IMG_SIZE, IMG_SIZE)
#       5 )
#       6 img_array = keras.preprocessing.image.img_to_array(img)
#
# ~/anaconda3/envs/tf-gpu/lib/python3.7/site-packages/keras/preprocessing/image.py in load_img(path, grayscale, color_mode, target_size, interpolation)
#     312   """
#     313   return image.load_img(path, grayscale=grayscale, color_mode=color_mode,
# --> 314                         target_size=target_size, interpolation=interpolation)
#     315
#     316
#
# ~/anaconda3/envs/tf-gpu/lib/python3.7/site-packages/keras_preprocessing/image/utils.py in load_img(path, grayscale, color_mode, target_size, interpolation)
#     111         raise ImportError('Could not import PIL.Image. '
#     112                           'The use of `load_img` requires PIL.')
# --> 113     with open(path, 'rb') as f:
#     114         img = pil_image.open(io.BytesIO(f.read()))
#     115         if color_mode == 'grayscale':
#
# FileNotFoundError: [Errno 2] No such file or directory: './data/humanModel_v0_dataset_split/val/38/-Mr4e3Fomo72jz0zfTgB_14.png'
