# %%
# https://pyimagesearch.com/2018/06/04/keras-multiple-outputs-and-multiple-losses/

import numpy as np
import random
import os

# ! pip install split-folders
from imutils import paths
import cv2

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import regularizers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, Flatten, Dropout
from tensorflow.keras.optimizers import Adam

from tensorflow.keras.preprocessing.image import img_to_array
# from tensorflow.keras.preprocessing import image


from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer, LabelEncoder

import matplotlib.pyplot as plt

rs = 42
def reset_random_seeds(rs):
   os.environ['PYTHONHASHSEED']=str(rs)
   tf.random.set_seed(rs)
   np.random.seed(rs)
   random.seed(rs)
reset_random_seeds(rs)

map_dir = 'map 5'

# %% [markdown]
# # Part 1 - Data Preprocessing

# %% [markdown]
# ## Split into train , test data

# %%
# grab the image paths and randomly shuffle them
print("[INFO] loading images...")
imagePaths = sorted(list(paths.list_images('./data/humanModel_v1_dataset/')))
random.shuffle(imagePaths)

# initialize the data
data = []
actionLabels = []
rateLabels = []
# Out:
# [INFO] loading images...

# %% [markdown]
# ### Preprocessing the Training set

# %%
batch_size = 64
IMG_SIZE = 10

# loop over the input images
for imagePath in imagePaths:
	# load the image, pre-process it, and store it in the data list
	image = cv2.imread(imagePath)
	# image = cv2.resize(image, (IMG_SIZE, IMG_SIZE))
	# image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
	image = img_to_array(image)
	data.append(image)
	# extract the action and rate from the path and
	# update the respective lists
	(action, rate) = imagePath.split(os.path.sep)[-2].split("_")
	actionLabels.append(action)
	rateLabels.append(rate)

# %%
# scale the raw pixel intensities to the range [0, 1] and convert to
# a NumPy array
data = np.array(data, dtype="float") / 255.0
print("[INFO] data matrix: {} images ({:.2f}MB)".format(
	len(imagePaths), data.nbytes / (1024 * 1000.0)))
# convert the label lists to NumPy arrays prior to binarization
actionLabels = np.array(actionLabels)
rateLabels = np.array(rateLabels)
# binarize both sets of labels
print("[INFO] binarizing labels...")
actionLB = LabelBinarizer()
rateLB = LabelEncoder()
actionLabels = actionLB.fit_transform(actionLabels)
rateLabels = rateLB.fit_transform(rateLabels) / 7

# partition the data into training and testing splits using 80% of
# the data for training and the remaining 20% for testing
split = train_test_split(data, actionLabels, rateLabels, test_size=0.2, random_state=42)
(trainX, testX, trainActionY, testActionY, trainRateY, testRateY) = split
# Out:
# [INFO] data matrix: 1056 images (2.48MB)
# [INFO] binarizing labels...

# %%
ACTION_NUM = 5

# Define model layers.
input_layer = Input(shape=(IMG_SIZE,IMG_SIZE,3))
X = Conv2D(8, 4, padding='same', activation='relu', kernel_regularizer=regularizers.l2(0.01))(input_layer)
X = Conv2D(16, 4, padding='same', activation='relu', kernel_regularizer=regularizers.l2(0.01))(X)
X = Conv2D(16, 3, padding='same', activation='relu', kernel_regularizer=regularizers.l2(0.01))(X)
X = MaxPooling2D()(X)
X = Conv2D(8, 3, padding='same', activation='relu', kernel_regularizer=regularizers.l2(0.01))(X)
X = Dropout(0.5)(X)
X = Flatten()(X)
X = Dense(32, activation='relu', kernel_regularizer=regularizers.l2(0.01))(X)

# rate output will be fed from the second dense
rate_output = Dense(1, activation='linear', name='rate_output')(X)

# Define the model with the input layer 
# and a list of output layers
model = Model(inputs=input_layer,outputs=[rate_output])

# %%
# ACTION_NUM = 5

# # Define model layers.
# input_layer = Input(shape=(IMG_SIZE,IMG_SIZE,3))
# X = Conv2D(8, 4, padding='same', activation='relu', kernel_regularizer=regularizers.l2(0.01))(input_layer)
# X = Conv2D(16, 4, padding='same', activation='relu', kernel_regularizer=regularizers.l2(0.01))(X)
# X = Conv2D(16, 3, padding='same', activation='relu', kernel_regularizer=regularizers.l2(0.01))(X)
# X = MaxPooling2D()(X)
# X = Conv2D(8, 3, padding='same', activation='relu', kernel_regularizer=regularizers.l2(0.01))(X)
# X = Dropout(0.5)(X)
# X = Flatten()(X)
# X = Dense(32, activation='relu', kernel_regularizer=regularizers.l2(0.01))(X)

# # action output will be fed from the first dense
# action_output = Dense(ACTION_NUM, activation='softmax', name='action_output')(X)
# # rate output will be fed from the second dense
# rate_output = Dense(1, activation='linear', name='rate_output')(X)

# # Define the model with the input layer 
# # and a list of output layers
# model = Model(inputs=input_layer,outputs=[action_output, rate_output])

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 10, 10, 3)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 10, 10, 8)         392
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 10, 10, 16)        2064
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 10, 10, 16)        2320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 5, 5, 16)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 5, 5, 8)           1160
# _________________________________________________________________
# dropout (Dropout)            (None, 5, 5, 8)           0
# _________________________________________________________________
# flatten (Flatten)            (None, 200)               0
# _________________________________________________________________
# dense (Dense)                (None, 32)                6432
# _________________________________________________________________
# rate_output (Dense)          (None, 1)                 33
# =================================================================
# Total params: 12,401
# Trainable params: 12,401
# Non-trainable params: 0
# _________________________________________________________________

# %%
# # initialize the number of epochs to train for, initial learning rate,
# # batch size, and image dimensions
# EPOCHS = 350
# INIT_LR = 1e-3

# # define two dictionaries: one that specifies the loss method for
# # each output of the network along with a second dictionary that
# # specifies the weight per loss
# losses = {
# 	"action_output": "categorical_crossentropy",
# 	"rate_output": "mse",
# }
# lossWeights = {"action_output": 0.7, "rate_output": 0.3}
# # initialize the optimizer and compile the model
# print("[INFO] compiling model...")
# opt = Adam(learning_rate=INIT_LR, decay=INIT_LR / EPOCHS)
# model.compile(optimizer=opt, loss=losses, loss_weights=lossWeights,
# 	metrics=["accuracy"])

# %%
from tensorflow.keras import backend as K
def rmse(y_true, y_pred):
    return K.sqrt(K.mean(K.square(y_pred - y_true)))

# initialize the number of epochs to train for, initial learning rate,
# batch size, and image dimensions
EPOCHS = 350
INIT_LR = 1e-3

# initialize the optimizer and compile the model
print("[INFO] compiling model...")
opt = Adam(learning_rate=INIT_LR, decay=INIT_LR / EPOCHS)
model.compile(loss= rmse, optimizer=opt, metrics=[rmse])
# Out:
# [INFO] compiling model...

# %%
# # train the network to perform multi-output classification
# history = model.fit(x=trainX,
# 	y={"action_output": trainActionY, "rate_output": trainRateY},
# 	validation_data=(testX,
# 		{"action_output": testActionY, "rate_output": testRateY}),
# 	epochs=EPOCHS)
# # save the model to disk
# # print("[INFO] serializing network...")
# # model.save(args["model"], save_format="h5")

# %%
# train the network to perform multi-output classification
history = model.fit(x=trainX,
	y={"rate_output": trainRateY},
	validation_data=(testX,
		{"rate_output": testRateY}),
	epochs=EPOCHS)
# save the model to disk
# print("[INFO] serializing network...")
# model.save(args["model"], save_format="h5")
# Out:
# Epoch 1/350
# 27/27 [==============================] - 1s 10ms/step - loss: 1.1480 - rmse: 0.3296 - val_loss: 0.9503 - val_rmse: 0.2720
# Epoch 2/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.8528 - rmse: 0.2747 - val_loss: 0.7400 - val_rmse: 0.2663
# Epoch 3/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6835 - rmse: 0.2790 - val_loss: 0.5931 - val_rmse: 0.2580
# Epoch 4/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5624 - rmse: 0.2734 - val_loss: 0.5015 - val_rmse: 0.2606
# Epoch 5/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4772 - rmse: 0.2676 - val_loss: 0.4359 - val_rmse: 0.2575
# Epoch 6/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4309 - rmse: 0.2748 - val_loss: 0.3960 - val_rmse: 0.2634
# Epoch 7/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.3895 - rmse: 0.2702 - val_loss: 0.3593 - val_rmse: 0.2566
# Epoch 8/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.3597 - rmse: 0.2674 - val_loss: 0.3366 - val_rmse: 0.2557
# Epoch 9/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.3398 - rmse: 0.2643 - val_loss: 0.3192 - val_rmse: 0.2541
# Epoch 10/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.3258 - rmse: 0.2658 - val_loss: 0.3068 - val_rmse: 0.2536
# Epoch 11/350
# 27/27 [==============================] - 0s 4ms/step - loss: 0.3149 - rmse: 0.2663 - val_loss: 0.3043 - val_rmse: 0.2611
# Epoch 12/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.3102 - rmse: 0.2693 - val_loss: 0.2993 - val_rmse: 0.2609
# Epoch 13/350
# 27/27 [==============================] - 0s 5ms/step - loss: 0.3012 - rmse: 0.2656 - val_loss: 0.2891 - val_rmse: 0.2565
# Epoch 14/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2964 - rmse: 0.2673 - val_loss: 0.2810 - val_rmse: 0.2536
# Epoch 15/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2927 - rmse: 0.2661 - val_loss: 0.2799 - val_rmse: 0.2561
# Epoch 16/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2873 - rmse: 0.2630 - val_loss: 0.2746 - val_rmse: 0.2538
# Epoch 17/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2851 - rmse: 0.2628 - val_loss: 0.2741 - val_rmse: 0.2550
# Epoch 18/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2841 - rmse: 0.2659 - val_loss: 0.2707 - val_rmse: 0.2544
# Epoch 19/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2806 - rmse: 0.2635 - val_loss: 0.2688 - val_rmse: 0.2537
# Epoch 20/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2794 - rmse: 0.2643 - val_loss: 0.2692 - val_rmse: 0.2545
# Epoch 21/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2811 - rmse: 0.2667 - val_loss: 0.2664 - val_rmse: 0.2540
# Epoch 22/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2798 - rmse: 0.2664 - val_loss: 0.2655 - val_rmse: 0.2535
# Epoch 23/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2786 - rmse: 0.2676 - val_loss: 0.2649 - val_rmse: 0.2543
# Epoch 24/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2818 - rmse: 0.2710 - val_loss: 0.2652 - val_rmse: 0.2557
# Epoch 25/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2761 - rmse: 0.2648 - val_loss: 0.2634 - val_rmse: 0.2536
# Epoch 26/350
# 27/27 [==============================] - 0s 4ms/step - loss: 0.2751 - rmse: 0.2637 - val_loss: 0.2698 - val_rmse: 0.2615
# Epoch 27/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2768 - rmse: 0.2681 - val_loss: 0.2626 - val_rmse: 0.2539
# Epoch 28/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2758 - rmse: 0.2674 - val_loss: 0.2627 - val_rmse: 0.2540
# Epoch 29/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2746 - rmse: 0.2663 - val_loss: 0.2630 - val_rmse: 0.2542
# Epoch 30/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2752 - rmse: 0.2669 - val_loss: 0.2653 - val_rmse: 0.2580
# Epoch 31/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2734 - rmse: 0.2649 - val_loss: 0.2643 - val_rmse: 0.2571
# Epoch 32/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2761 - rmse: 0.2682 - val_loss: 0.2611 - val_rmse: 0.2538
# Epoch 33/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2736 - rmse: 0.2666 - val_loss: 0.2667 - val_rmse: 0.2585
# Epoch 34/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2741 - rmse: 0.2672 - val_loss: 0.2627 - val_rmse: 0.2562
# Epoch 35/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2738 - rmse: 0.2649 - val_loss: 0.2640 - val_rmse: 0.2564
# Epoch 36/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2736 - rmse: 0.2646 - val_loss: 0.2621 - val_rmse: 0.2557
# Epoch 37/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2759 - rmse: 0.2700 - val_loss: 0.2649 - val_rmse: 0.2592
# Epoch 38/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2730 - rmse: 0.2658 - val_loss: 0.2633 - val_rmse: 0.2564
# Epoch 39/350
# 27/27 [==============================] - 0s 4ms/step - loss: 0.2788 - rmse: 0.2737 - val_loss: 0.2608 - val_rmse: 0.2546
# Epoch 40/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2728 - rmse: 0.2650 - val_loss: 0.2637 - val_rmse: 0.2582
# Epoch 41/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2727 - rmse: 0.2658 - val_loss: 0.2667 - val_rmse: 0.2615
# Epoch 42/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2728 - rmse: 0.2658 - val_loss: 0.2596 - val_rmse: 0.2534
# Epoch 43/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2742 - rmse: 0.2681 - val_loss: 0.2617 - val_rmse: 0.2564
# Epoch 44/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2733 - rmse: 0.2678 - val_loss: 0.2607 - val_rmse: 0.2552
# Epoch 45/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2737 - rmse: 0.2672 - val_loss: 0.2597 - val_rmse: 0.2538
# Epoch 46/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2720 - rmse: 0.2671 - val_loss: 0.2595 - val_rmse: 0.2535
# Epoch 47/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2747 - rmse: 0.2676 - val_loss: 0.2601 - val_rmse: 0.2544
# Epoch 48/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2748 - rmse: 0.2691 - val_loss: 0.2601 - val_rmse: 0.2546
# Epoch 49/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2722 - rmse: 0.2646 - val_loss: 0.2605 - val_rmse: 0.2551
# Epoch 50/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2714 - rmse: 0.2645 - val_loss: 0.2592 - val_rmse: 0.2534
# Epoch 51/350
# 27/27 [==============================] - 0s 5ms/step - loss: 0.2729 - rmse: 0.2672 - val_loss: 0.2592 - val_rmse: 0.2532
# Epoch 52/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2722 - rmse: 0.2654 - val_loss: 0.2592 - val_rmse: 0.2533
# Epoch 53/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2704 - rmse: 0.2636 - val_loss: 0.2656 - val_rmse: 0.2604
# Epoch 54/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2741 - rmse: 0.2665 - val_loss: 0.2613 - val_rmse: 0.2549
# Epoch 55/350
# 27/27 [==============================] - 0s 4ms/step - loss: 0.2723 - rmse: 0.2643 - val_loss: 0.2609 - val_rmse: 0.2543
# Epoch 56/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2724 - rmse: 0.2656 - val_loss: 0.2586 - val_rmse: 0.2525
# Epoch 57/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2712 - rmse: 0.2641 - val_loss: 0.2594 - val_rmse: 0.2536
# Epoch 58/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2732 - rmse: 0.2672 - val_loss: 0.2592 - val_rmse: 0.2528
# Epoch 59/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2713 - rmse: 0.2654 - val_loss: 0.2590 - val_rmse: 0.2530
# Epoch 60/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2722 - rmse: 0.2656 - val_loss: 0.2674 - val_rmse: 0.2624
# Epoch 61/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2738 - rmse: 0.2676 - val_loss: 0.2653 - val_rmse: 0.2605
# Epoch 62/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2727 - rmse: 0.2659 - val_loss: 0.2594 - val_rmse: 0.2539
# Epoch 63/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2728 - rmse: 0.2666 - val_loss: 0.2681 - val_rmse: 0.2633
# Epoch 64/350
# 27/27 [==============================] - 0s 4ms/step - loss: 0.2733 - rmse: 0.2669 - val_loss: 0.2590 - val_rmse: 0.2533
# Epoch 65/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2712 - rmse: 0.2672 - val_loss: 0.2592 - val_rmse: 0.2534
# Epoch 66/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2705 - rmse: 0.2625 - val_loss: 0.2624 - val_rmse: 0.2557
# Epoch 67/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2706 - rmse: 0.2635 - val_loss: 0.2626 - val_rmse: 0.2572
# Epoch 68/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2702 - rmse: 0.2629 - val_loss: 0.2609 - val_rmse: 0.2550
# Epoch 69/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2714 - rmse: 0.2654 - val_loss: 0.2586 - val_rmse: 0.2523
# Epoch 70/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2738 - rmse: 0.2674 - val_loss: 0.2599 - val_rmse: 0.2541
# Epoch 71/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2716 - rmse: 0.2631 - val_loss: 0.2595 - val_rmse: 0.2538
# Epoch 72/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2730 - rmse: 0.2665 - val_loss: 0.2589 - val_rmse: 0.2529
# Epoch 73/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2722 - rmse: 0.2660 - val_loss: 0.2611 - val_rmse: 0.2557
# Epoch 74/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2718 - rmse: 0.2658 - val_loss: 0.2593 - val_rmse: 0.2530
# Epoch 75/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2704 - rmse: 0.2646 - val_loss: 0.2591 - val_rmse: 0.2535
# Epoch 76/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2721 - rmse: 0.2661 - val_loss: 0.2587 - val_rmse: 0.2527
# Epoch 77/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2734 - rmse: 0.2672 - val_loss: 0.2586 - val_rmse: 0.2527
# Epoch 78/350
# 27/27 [==============================] - 0s 4ms/step - loss: 0.2708 - rmse: 0.2639 - val_loss: 0.2589 - val_rmse: 0.2527
# Epoch 79/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2716 - rmse: 0.2642 - val_loss: 0.2610 - val_rmse: 0.2545
# Epoch 80/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2697 - rmse: 0.2617 - val_loss: 0.2588 - val_rmse: 0.2526
# Epoch 81/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2723 - rmse: 0.2661 - val_loss: 0.2586 - val_rmse: 0.2525
# Epoch 82/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2723 - rmse: 0.2658 - val_loss: 0.2595 - val_rmse: 0.2537
# Epoch 83/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2717 - rmse: 0.2654 - val_loss: 0.2585 - val_rmse: 0.2526
# Epoch 84/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2709 - rmse: 0.2641 - val_loss: 0.2608 - val_rmse: 0.2554
# Epoch 85/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2716 - rmse: 0.2643 - val_loss: 0.2631 - val_rmse: 0.2577
# Epoch 86/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2738 - rmse: 0.2688 - val_loss: 0.2590 - val_rmse: 0.2533
# Epoch 87/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2711 - rmse: 0.2650 - val_loss: 0.2591 - val_rmse: 0.2528
# Epoch 88/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2705 - rmse: 0.2645 - val_loss: 0.2588 - val_rmse: 0.2530
# Epoch 89/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2712 - rmse: 0.2639 - val_loss: 0.2611 - val_rmse: 0.2558
# Epoch 90/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2712 - rmse: 0.2657 - val_loss: 0.2706 - val_rmse: 0.2634
# Epoch 91/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2788 - rmse: 0.2732 - val_loss: 0.2611 - val_rmse: 0.2552
# Epoch 92/350
# 27/27 [==============================] - 0s 4ms/step - loss: 0.2725 - rmse: 0.2659 - val_loss: 0.2606 - val_rmse: 0.2554
# Epoch 93/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2707 - rmse: 0.2631 - val_loss: 0.2607 - val_rmse: 0.2553
# Epoch 94/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2708 - rmse: 0.2645 - val_loss: 0.2601 - val_rmse: 0.2548
# Epoch 95/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2712 - rmse: 0.2646 - val_loss: 0.2647 - val_rmse: 0.2596
# Epoch 96/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2748 - rmse: 0.2697 - val_loss: 0.2669 - val_rmse: 0.2624
# Epoch 97/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2725 - rmse: 0.2662 - val_loss: 0.2623 - val_rmse: 0.2574
# Epoch 98/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2727 - rmse: 0.2653 - val_loss: 0.2589 - val_rmse: 0.2531
# Epoch 99/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2694 - rmse: 0.2633 - val_loss: 0.2590 - val_rmse: 0.2529
# Epoch 100/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2703 - rmse: 0.2641 - val_loss: 0.2604 - val_rmse: 0.2549
# Epoch 101/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2718 - rmse: 0.2654 - val_loss: 0.2592 - val_rmse: 0.2537
# Epoch 102/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2700 - rmse: 0.2635 - val_loss: 0.2585 - val_rmse: 0.2528
# Epoch 103/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2712 - rmse: 0.2650 - val_loss: 0.2591 - val_rmse: 0.2534
# Epoch 104/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2707 - rmse: 0.2650 - val_loss: 0.2595 - val_rmse: 0.2538
# Epoch 105/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2725 - rmse: 0.2668 - val_loss: 0.2583 - val_rmse: 0.2525
# Epoch 106/350
# 27/27 [==============================] - 0s 4ms/step - loss: 0.2716 - rmse: 0.2664 - val_loss: 0.2592 - val_rmse: 0.2529
# Epoch 107/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2708 - rmse: 0.2654 - val_loss: 0.2590 - val_rmse: 0.2537
# Epoch 108/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2711 - rmse: 0.2628 - val_loss: 0.2698 - val_rmse: 0.2629
# Epoch 109/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2774 - rmse: 0.2721 - val_loss: 0.2621 - val_rmse: 0.2560
# Epoch 110/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2718 - rmse: 0.2677 - val_loss: 0.2614 - val_rmse: 0.2552
# Epoch 111/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2699 - rmse: 0.2637 - val_loss: 0.2597 - val_rmse: 0.2544
# Epoch 112/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2703 - rmse: 0.2630 - val_loss: 0.2584 - val_rmse: 0.2524
# Epoch 113/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2718 - rmse: 0.2653 - val_loss: 0.2636 - val_rmse: 0.2570
# Epoch 114/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2704 - rmse: 0.2645 - val_loss: 0.2591 - val_rmse: 0.2529
# Epoch 115/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2723 - rmse: 0.2657 - val_loss: 0.2588 - val_rmse: 0.2530
# Epoch 116/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2701 - rmse: 0.2635 - val_loss: 0.2584 - val_rmse: 0.2528
# Epoch 117/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2698 - rmse: 0.2638 - val_loss: 0.2582 - val_rmse: 0.2523
# Epoch 118/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2695 - rmse: 0.2629 - val_loss: 0.2611 - val_rmse: 0.2560
# Epoch 119/350
# 27/27 [==============================] - 0s 4ms/step - loss: 0.2701 - rmse: 0.2641 - val_loss: 0.2582 - val_rmse: 0.2524
# Epoch 120/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2707 - rmse: 0.2631 - val_loss: 0.2593 - val_rmse: 0.2527
# Epoch 121/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2710 - rmse: 0.2644 - val_loss: 0.2581 - val_rmse: 0.2521
# Epoch 122/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2705 - rmse: 0.2649 - val_loss: 0.2612 - val_rmse: 0.2560
# Epoch 123/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2707 - rmse: 0.2652 - val_loss: 0.2645 - val_rmse: 0.2597
# Epoch 124/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2711 - rmse: 0.2636 - val_loss: 0.2582 - val_rmse: 0.2524
# Epoch 125/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2682 - rmse: 0.2608 - val_loss: 0.2610 - val_rmse: 0.2545
# Epoch 126/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2721 - rmse: 0.2658 - val_loss: 0.2585 - val_rmse: 0.2529
# Epoch 127/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2708 - rmse: 0.2647 - val_loss: 0.2585 - val_rmse: 0.2525
# Epoch 128/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2708 - rmse: 0.2646 - val_loss: 0.2582 - val_rmse: 0.2524
# Epoch 129/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2717 - rmse: 0.2647 - val_loss: 0.2654 - val_rmse: 0.2606
# Epoch 130/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2723 - rmse: 0.2657 - val_loss: 0.2583 - val_rmse: 0.2526
# Epoch 131/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2701 - rmse: 0.2645 - val_loss: 0.2582 - val_rmse: 0.2523
# Epoch 132/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2717 - rmse: 0.2648 - val_loss: 0.2582 - val_rmse: 0.2524
# Epoch 133/350
# 27/27 [==============================] - 0s 4ms/step - loss: 0.2733 - rmse: 0.2666 - val_loss: 0.2609 - val_rmse: 0.2558
# Epoch 134/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2707 - rmse: 0.2637 - val_loss: 0.2590 - val_rmse: 0.2535
# Epoch 135/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2700 - rmse: 0.2622 - val_loss: 0.2613 - val_rmse: 0.2560
# Epoch 136/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2708 - rmse: 0.2635 - val_loss: 0.2595 - val_rmse: 0.2542
# Epoch 137/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2716 - rmse: 0.2665 - val_loss: 0.2585 - val_rmse: 0.2526
# Epoch 138/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2706 - rmse: 0.2647 - val_loss: 0.2593 - val_rmse: 0.2538
# Epoch 139/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2713 - rmse: 0.2647 - val_loss: 0.2596 - val_rmse: 0.2534
# Epoch 140/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2714 - rmse: 0.2641 - val_loss: 0.2590 - val_rmse: 0.2527
# Epoch 141/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2708 - rmse: 0.2660 - val_loss: 0.2584 - val_rmse: 0.2524
# Epoch 142/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2698 - rmse: 0.2623 - val_loss: 0.2590 - val_rmse: 0.2526
# Epoch 143/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2699 - rmse: 0.2634 - val_loss: 0.2586 - val_rmse: 0.2530
# Epoch 144/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2712 - rmse: 0.2631 - val_loss: 0.2581 - val_rmse: 0.2521
# Epoch 145/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2684 - rmse: 0.2617 - val_loss: 0.2591 - val_rmse: 0.2527
# Epoch 146/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2694 - rmse: 0.2629 - val_loss: 0.2582 - val_rmse: 0.2521
# Epoch 147/350
# 27/27 [==============================] - 0s 4ms/step - loss: 0.2703 - rmse: 0.2620 - val_loss: 0.2608 - val_rmse: 0.2540
# Epoch 148/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2719 - rmse: 0.2654 - val_loss: 0.2582 - val_rmse: 0.2523
# Epoch 149/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2720 - rmse: 0.2657 - val_loss: 0.2701 - val_rmse: 0.2656
# Epoch 150/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2698 - rmse: 0.2630 - val_loss: 0.2609 - val_rmse: 0.2558
# Epoch 151/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2731 - rmse: 0.2661 - val_loss: 0.2589 - val_rmse: 0.2535
# Epoch 152/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2715 - rmse: 0.2650 - val_loss: 0.2591 - val_rmse: 0.2537
# Epoch 153/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2709 - rmse: 0.2646 - val_loss: 0.2585 - val_rmse: 0.2524
# Epoch 154/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2703 - rmse: 0.2648 - val_loss: 0.2592 - val_rmse: 0.2538
# Epoch 155/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2714 - rmse: 0.2652 - val_loss: 0.2596 - val_rmse: 0.2543
# Epoch 156/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2700 - rmse: 0.2639 - val_loss: 0.2580 - val_rmse: 0.2520
# Epoch 157/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2722 - rmse: 0.2654 - val_loss: 0.2606 - val_rmse: 0.2554
# Epoch 158/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2724 - rmse: 0.2652 - val_loss: 0.2683 - val_rmse: 0.2638
# Epoch 159/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2752 - rmse: 0.2700 - val_loss: 0.2599 - val_rmse: 0.2549
# Epoch 160/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2710 - rmse: 0.2654 - val_loss: 0.2594 - val_rmse: 0.2542
# Epoch 161/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2711 - rmse: 0.2638 - val_loss: 0.2584 - val_rmse: 0.2525
# Epoch 162/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2709 - rmse: 0.2643 - val_loss: 0.2584 - val_rmse: 0.2530
# Epoch 163/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2699 - rmse: 0.2624 - val_loss: 0.2591 - val_rmse: 0.2530
# Epoch 164/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2719 - rmse: 0.2647 - val_loss: 0.2582 - val_rmse: 0.2523
# Epoch 165/350
# 27/27 [==============================] - 0s 4ms/step - loss: 0.2688 - rmse: 0.2626 - val_loss: 0.2582 - val_rmse: 0.2521
# Epoch 166/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2702 - rmse: 0.2624 - val_loss: 0.2580 - val_rmse: 0.2522
# Epoch 167/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2686 - rmse: 0.2619 - val_loss: 0.2579 - val_rmse: 0.2521
# Epoch 168/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2698 - rmse: 0.2622 - val_loss: 0.2581 - val_rmse: 0.2522
# Epoch 169/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2696 - rmse: 0.2626 - val_loss: 0.2581 - val_rmse: 0.2519
# Epoch 170/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2702 - rmse: 0.2634 - val_loss: 0.2579 - val_rmse: 0.2519
# Epoch 171/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2696 - rmse: 0.2629 - val_loss: 0.2596 - val_rmse: 0.2543
# Epoch 172/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2716 - rmse: 0.2645 - val_loss: 0.2607 - val_rmse: 0.2555
# Epoch 173/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2692 - rmse: 0.2624 - val_loss: 0.2580 - val_rmse: 0.2520
# Epoch 174/350
# 27/27 [==============================] - 0s 4ms/step - loss: 0.2717 - rmse: 0.2652 - val_loss: 0.2588 - val_rmse: 0.2532
# Epoch 175/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2697 - rmse: 0.2636 - val_loss: 0.2582 - val_rmse: 0.2522
# Epoch 176/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2708 - rmse: 0.2652 - val_loss: 0.2611 - val_rmse: 0.2559
# Epoch 177/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2699 - rmse: 0.2639 - val_loss: 0.2580 - val_rmse: 0.2519
# Epoch 178/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2691 - rmse: 0.2642 - val_loss: 0.2622 - val_rmse: 0.2570
# Epoch 179/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2707 - rmse: 0.2640 - val_loss: 0.2627 - val_rmse: 0.2577
# Epoch 180/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2712 - rmse: 0.2644 - val_loss: 0.2585 - val_rmse: 0.2529
# Epoch 181/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2705 - rmse: 0.2634 - val_loss: 0.2578 - val_rmse: 0.2518
# Epoch 182/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2703 - rmse: 0.2638 - val_loss: 0.2578 - val_rmse: 0.2518
# Epoch 183/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2691 - rmse: 0.2617 - val_loss: 0.2598 - val_rmse: 0.2543
# Epoch 184/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2692 - rmse: 0.2612 - val_loss: 0.2592 - val_rmse: 0.2538
# Epoch 185/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2702 - rmse: 0.2642 - val_loss: 0.2580 - val_rmse: 0.2521
# Epoch 186/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2709 - rmse: 0.2637 - val_loss: 0.2578 - val_rmse: 0.2520
# Epoch 187/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2686 - rmse: 0.2623 - val_loss: 0.2594 - val_rmse: 0.2540
# Epoch 188/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2719 - rmse: 0.2644 - val_loss: 0.2579 - val_rmse: 0.2520
# Epoch 189/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2712 - rmse: 0.2638 - val_loss: 0.2606 - val_rmse: 0.2555
# Epoch 190/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2696 - rmse: 0.2631 - val_loss: 0.2583 - val_rmse: 0.2523
# Epoch 191/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2695 - rmse: 0.2633 - val_loss: 0.2581 - val_rmse: 0.2523
# Epoch 192/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2695 - rmse: 0.2635 - val_loss: 0.2582 - val_rmse: 0.2524
# Epoch 193/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2708 - rmse: 0.2632 - val_loss: 0.2579 - val_rmse: 0.2520
# Epoch 194/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2709 - rmse: 0.2641 - val_loss: 0.2591 - val_rmse: 0.2528
# Epoch 195/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2721 - rmse: 0.2675 - val_loss: 0.2608 - val_rmse: 0.2546
# Epoch 196/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2689 - rmse: 0.2613 - val_loss: 0.2685 - val_rmse: 0.2618
# Epoch 197/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2727 - rmse: 0.2647 - val_loss: 0.2599 - val_rmse: 0.2538
# Epoch 198/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2728 - rmse: 0.2683 - val_loss: 0.2591 - val_rmse: 0.2531
# Epoch 199/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2687 - rmse: 0.2630 - val_loss: 0.2601 - val_rmse: 0.2538
# Epoch 200/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2720 - rmse: 0.2661 - val_loss: 0.2585 - val_rmse: 0.2527
# Epoch 201/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2709 - rmse: 0.2648 - val_loss: 0.2596 - val_rmse: 0.2545
# Epoch 202/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2693 - rmse: 0.2649 - val_loss: 0.2597 - val_rmse: 0.2546
# Epoch 203/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2716 - rmse: 0.2664 - val_loss: 0.2586 - val_rmse: 0.2533
# Epoch 204/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2697 - rmse: 0.2636 - val_loss: 0.2588 - val_rmse: 0.2534
# Epoch 205/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2683 - rmse: 0.2633 - val_loss: 0.2590 - val_rmse: 0.2535
# Epoch 206/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2689 - rmse: 0.2628 - val_loss: 0.2596 - val_rmse: 0.2543
# Epoch 207/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2688 - rmse: 0.2621 - val_loss: 0.2604 - val_rmse: 0.2539
# Epoch 208/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2710 - rmse: 0.2660 - val_loss: 0.2596 - val_rmse: 0.2532
# Epoch 209/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2737 - rmse: 0.2662 - val_loss: 0.2601 - val_rmse: 0.2550
# Epoch 210/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2690 - rmse: 0.2612 - val_loss: 0.2597 - val_rmse: 0.2535
# Epoch 211/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2695 - rmse: 0.2618 - val_loss: 0.2590 - val_rmse: 0.2536
# Epoch 212/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2691 - rmse: 0.2615 - val_loss: 0.2591 - val_rmse: 0.2537
# Epoch 213/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2693 - rmse: 0.2625 - val_loss: 0.2599 - val_rmse: 0.2547
# Epoch 214/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2703 - rmse: 0.2648 - val_loss: 0.2579 - val_rmse: 0.2522
# Epoch 215/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2692 - rmse: 0.2622 - val_loss: 0.2577 - val_rmse: 0.2520
# Epoch 216/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2705 - rmse: 0.2650 - val_loss: 0.2590 - val_rmse: 0.2537
# Epoch 217/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2706 - rmse: 0.2649 - val_loss: 0.2578 - val_rmse: 0.2522
# Epoch 218/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2689 - rmse: 0.2618 - val_loss: 0.2579 - val_rmse: 0.2524
# Epoch 219/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2704 - rmse: 0.2643 - val_loss: 0.2603 - val_rmse: 0.2551
# Epoch 220/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2720 - rmse: 0.2656 - val_loss: 0.2582 - val_rmse: 0.2521
# Epoch 221/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2709 - rmse: 0.2662 - val_loss: 0.2591 - val_rmse: 0.2528
# Epoch 222/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2710 - rmse: 0.2652 - val_loss: 0.2577 - val_rmse: 0.2521
# Epoch 223/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2709 - rmse: 0.2643 - val_loss: 0.2608 - val_rmse: 0.2544
# Epoch 224/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2699 - rmse: 0.2635 - val_loss: 0.2591 - val_rmse: 0.2527
# Epoch 225/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2703 - rmse: 0.2624 - val_loss: 0.2583 - val_rmse: 0.2520
# Epoch 226/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2700 - rmse: 0.2626 - val_loss: 0.2577 - val_rmse: 0.2518
# Epoch 227/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2692 - rmse: 0.2599 - val_loss: 0.2593 - val_rmse: 0.2530
# Epoch 228/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2748 - rmse: 0.2684 - val_loss: 0.2600 - val_rmse: 0.2538
# Epoch 229/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2688 - rmse: 0.2616 - val_loss: 0.2576 - val_rmse: 0.2520
# Epoch 230/350
# 27/27 [==============================] - 0s 4ms/step - loss: 0.2743 - rmse: 0.2683 - val_loss: 0.2580 - val_rmse: 0.2524
# Epoch 231/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2702 - rmse: 0.2629 - val_loss: 0.2594 - val_rmse: 0.2540
# Epoch 232/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2684 - rmse: 0.2618 - val_loss: 0.2629 - val_rmse: 0.2563
# Epoch 233/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2709 - rmse: 0.2644 - val_loss: 0.2584 - val_rmse: 0.2521
# Epoch 234/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2690 - rmse: 0.2623 - val_loss: 0.2582 - val_rmse: 0.2521
# Epoch 235/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2701 - rmse: 0.2630 - val_loss: 0.2576 - val_rmse: 0.2519
# Epoch 236/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2702 - rmse: 0.2632 - val_loss: 0.2620 - val_rmse: 0.2570
# Epoch 237/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2695 - rmse: 0.2632 - val_loss: 0.2621 - val_rmse: 0.2574
# Epoch 238/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2720 - rmse: 0.2660 - val_loss: 0.2678 - val_rmse: 0.2634
# Epoch 239/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2749 - rmse: 0.2690 - val_loss: 0.2676 - val_rmse: 0.2632
# Epoch 240/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2726 - rmse: 0.2663 - val_loss: 0.2579 - val_rmse: 0.2524
# Epoch 241/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2712 - rmse: 0.2636 - val_loss: 0.2588 - val_rmse: 0.2535
# Epoch 242/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2724 - rmse: 0.2654 - val_loss: 0.2580 - val_rmse: 0.2526
# Epoch 243/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2703 - rmse: 0.2637 - val_loss: 0.2587 - val_rmse: 0.2535
# Epoch 244/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2715 - rmse: 0.2665 - val_loss: 0.2586 - val_rmse: 0.2534
# Epoch 245/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2699 - rmse: 0.2639 - val_loss: 0.2599 - val_rmse: 0.2548
# Epoch 246/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2760 - rmse: 0.2695 - val_loss: 0.2582 - val_rmse: 0.2526
# Epoch 247/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2711 - rmse: 0.2642 - val_loss: 0.2582 - val_rmse: 0.2525
# Epoch 248/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2690 - rmse: 0.2617 - val_loss: 0.2577 - val_rmse: 0.2520
# Epoch 249/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2710 - rmse: 0.2661 - val_loss: 0.2644 - val_rmse: 0.2575
# Epoch 250/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2730 - rmse: 0.2676 - val_loss: 0.2585 - val_rmse: 0.2530
# Epoch 251/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2701 - rmse: 0.2635 - val_loss: 0.2603 - val_rmse: 0.2552
# Epoch 252/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2693 - rmse: 0.2625 - val_loss: 0.2585 - val_rmse: 0.2529
# Epoch 253/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2698 - rmse: 0.2624 - val_loss: 0.2576 - val_rmse: 0.2520
# Epoch 254/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2700 - rmse: 0.2629 - val_loss: 0.2588 - val_rmse: 0.2525
# Epoch 255/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2701 - rmse: 0.2633 - val_loss: 0.2592 - val_rmse: 0.2538
# Epoch 256/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2711 - rmse: 0.2644 - val_loss: 0.2576 - val_rmse: 0.2517
# Epoch 257/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2677 - rmse: 0.2612 - val_loss: 0.2575 - val_rmse: 0.2515
# Epoch 258/350
# 27/27 [==============================] - 0s 4ms/step - loss: 0.2698 - rmse: 0.2633 - val_loss: 0.2574 - val_rmse: 0.2517
# Epoch 259/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2700 - rmse: 0.2645 - val_loss: 0.2618 - val_rmse: 0.2567
# Epoch 260/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2694 - rmse: 0.2621 - val_loss: 0.2611 - val_rmse: 0.2544
# Epoch 261/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2704 - rmse: 0.2651 - val_loss: 0.2576 - val_rmse: 0.2515
# Epoch 262/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2689 - rmse: 0.2617 - val_loss: 0.2575 - val_rmse: 0.2515
# Epoch 263/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2688 - rmse: 0.2621 - val_loss: 0.2575 - val_rmse: 0.2518
# Epoch 264/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2691 - rmse: 0.2624 - val_loss: 0.2594 - val_rmse: 0.2539
# Epoch 265/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2691 - rmse: 0.2633 - val_loss: 0.2591 - val_rmse: 0.2538
# Epoch 266/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2729 - rmse: 0.2665 - val_loss: 0.2582 - val_rmse: 0.2527
# Epoch 267/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2695 - rmse: 0.2625 - val_loss: 0.2576 - val_rmse: 0.2518
# Epoch 268/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2708 - rmse: 0.2634 - val_loss: 0.2627 - val_rmse: 0.2561
# Epoch 269/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2718 - rmse: 0.2655 - val_loss: 0.2575 - val_rmse: 0.2519
# Epoch 270/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2697 - rmse: 0.2621 - val_loss: 0.2590 - val_rmse: 0.2528
# Epoch 271/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2724 - rmse: 0.2650 - val_loss: 0.2575 - val_rmse: 0.2516
# Epoch 272/350
# 27/27 [==============================] - 0s 4ms/step - loss: 0.2699 - rmse: 0.2642 - val_loss: 0.2589 - val_rmse: 0.2535
# Epoch 273/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2692 - rmse: 0.2622 - val_loss: 0.2574 - val_rmse: 0.2515
# Epoch 274/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2735 - rmse: 0.2695 - val_loss: 0.2580 - val_rmse: 0.2525
# Epoch 275/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2705 - rmse: 0.2640 - val_loss: 0.2582 - val_rmse: 0.2524
# Epoch 276/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2687 - rmse: 0.2635 - val_loss: 0.2575 - val_rmse: 0.2516
# Epoch 277/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2682 - rmse: 0.2609 - val_loss: 0.2575 - val_rmse: 0.2517
# Epoch 278/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2706 - rmse: 0.2642 - val_loss: 0.2574 - val_rmse: 0.2517
# Epoch 279/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2689 - rmse: 0.2624 - val_loss: 0.2572 - val_rmse: 0.2513
# Epoch 280/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2684 - rmse: 0.2625 - val_loss: 0.2575 - val_rmse: 0.2516
# Epoch 281/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2706 - rmse: 0.2644 - val_loss: 0.2588 - val_rmse: 0.2535
# Epoch 282/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2696 - rmse: 0.2616 - val_loss: 0.2577 - val_rmse: 0.2520
# Epoch 283/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2689 - rmse: 0.2626 - val_loss: 0.2574 - val_rmse: 0.2517
# Epoch 284/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2715 - rmse: 0.2657 - val_loss: 0.2608 - val_rmse: 0.2559
# Epoch 285/350
# 27/27 [==============================] - 0s 5ms/step - loss: 0.2722 - rmse: 0.2644 - val_loss: 0.2577 - val_rmse: 0.2522
# Epoch 286/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2712 - rmse: 0.2650 - val_loss: 0.2581 - val_rmse: 0.2523
# Epoch 287/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2708 - rmse: 0.2646 - val_loss: 0.2578 - val_rmse: 0.2520
# Epoch 288/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2691 - rmse: 0.2640 - val_loss: 0.2574 - val_rmse: 0.2518
# Epoch 289/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2698 - rmse: 0.2631 - val_loss: 0.2579 - val_rmse: 0.2518
# Epoch 290/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2710 - rmse: 0.2655 - val_loss: 0.2575 - val_rmse: 0.2519
# Epoch 291/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2696 - rmse: 0.2636 - val_loss: 0.2575 - val_rmse: 0.2518
# Epoch 292/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2683 - rmse: 0.2616 - val_loss: 0.2576 - val_rmse: 0.2519
# Epoch 293/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2693 - rmse: 0.2641 - val_loss: 0.2598 - val_rmse: 0.2545
# Epoch 294/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2690 - rmse: 0.2628 - val_loss: 0.2573 - val_rmse: 0.2513
# Epoch 295/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2710 - rmse: 0.2644 - val_loss: 0.2610 - val_rmse: 0.2548
# Epoch 296/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2687 - rmse: 0.2600 - val_loss: 0.2624 - val_rmse: 0.2560
# Epoch 297/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2742 - rmse: 0.2681 - val_loss: 0.2576 - val_rmse: 0.2519
# Epoch 298/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2702 - rmse: 0.2614 - val_loss: 0.2581 - val_rmse: 0.2523
# Epoch 299/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2711 - rmse: 0.2659 - val_loss: 0.2575 - val_rmse: 0.2519
# Epoch 300/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2713 - rmse: 0.2634 - val_loss: 0.2575 - val_rmse: 0.2518
# Epoch 301/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2691 - rmse: 0.2626 - val_loss: 0.2636 - val_rmse: 0.2588
# Epoch 302/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2701 - rmse: 0.2642 - val_loss: 0.2582 - val_rmse: 0.2522
# Epoch 303/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2703 - rmse: 0.2644 - val_loss: 0.2574 - val_rmse: 0.2518
# Epoch 304/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2695 - rmse: 0.2622 - val_loss: 0.2581 - val_rmse: 0.2521
# Epoch 305/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2697 - rmse: 0.2648 - val_loss: 0.2626 - val_rmse: 0.2560
# Epoch 306/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2717 - rmse: 0.2658 - val_loss: 0.2577 - val_rmse: 0.2517
# Epoch 307/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2719 - rmse: 0.2659 - val_loss: 0.2574 - val_rmse: 0.2516
# Epoch 308/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2697 - rmse: 0.2634 - val_loss: 0.2582 - val_rmse: 0.2523
# Epoch 309/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2704 - rmse: 0.2627 - val_loss: 0.2593 - val_rmse: 0.2531
# Epoch 310/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2690 - rmse: 0.2632 - val_loss: 0.2577 - val_rmse: 0.2522
# Epoch 311/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2689 - rmse: 0.2627 - val_loss: 0.2572 - val_rmse: 0.2512
# Epoch 312/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2697 - rmse: 0.2632 - val_loss: 0.2601 - val_rmse: 0.2547
# Epoch 313/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2705 - rmse: 0.2652 - val_loss: 0.2591 - val_rmse: 0.2538
# Epoch 314/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2680 - rmse: 0.2612 - val_loss: 0.2577 - val_rmse: 0.2520
# Epoch 315/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2703 - rmse: 0.2646 - val_loss: 0.2595 - val_rmse: 0.2542
# Epoch 316/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2720 - rmse: 0.2653 - val_loss: 0.2574 - val_rmse: 0.2517
# Epoch 317/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2716 - rmse: 0.2648 - val_loss: 0.2634 - val_rmse: 0.2570
# Epoch 318/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2710 - rmse: 0.2662 - val_loss: 0.2626 - val_rmse: 0.2564
# Epoch 319/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2709 - rmse: 0.2645 - val_loss: 0.2575 - val_rmse: 0.2518
# Epoch 320/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2695 - rmse: 0.2633 - val_loss: 0.2583 - val_rmse: 0.2522
# Epoch 321/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2708 - rmse: 0.2653 - val_loss: 0.2577 - val_rmse: 0.2516
# Epoch 322/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2688 - rmse: 0.2628 - val_loss: 0.2573 - val_rmse: 0.2515
# Epoch 323/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2687 - rmse: 0.2615 - val_loss: 0.2624 - val_rmse: 0.2575
# Epoch 324/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2725 - rmse: 0.2670 - val_loss: 0.2657 - val_rmse: 0.2610
# Epoch 325/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2727 - rmse: 0.2668 - val_loss: 0.2584 - val_rmse: 0.2531
# Epoch 326/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2697 - rmse: 0.2638 - val_loss: 0.2596 - val_rmse: 0.2544
# Epoch 327/350
# 27/27 [==============================] - 0s 4ms/step - loss: 0.2676 - rmse: 0.2632 - val_loss: 0.2582 - val_rmse: 0.2521
# Epoch 328/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2704 - rmse: 0.2647 - val_loss: 0.2584 - val_rmse: 0.2531
# Epoch 329/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2727 - rmse: 0.2657 - val_loss: 0.2624 - val_rmse: 0.2575
# Epoch 330/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2705 - rmse: 0.2634 - val_loss: 0.2590 - val_rmse: 0.2539
# Epoch 331/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2699 - rmse: 0.2631 - val_loss: 0.2606 - val_rmse: 0.2543
# Epoch 332/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2697 - rmse: 0.2640 - val_loss: 0.2582 - val_rmse: 0.2528
# Epoch 333/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2693 - rmse: 0.2642 - val_loss: 0.2596 - val_rmse: 0.2543
# Epoch 334/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2690 - rmse: 0.2627 - val_loss: 0.2579 - val_rmse: 0.2518
# Epoch 335/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2698 - rmse: 0.2629 - val_loss: 0.2603 - val_rmse: 0.2538
# Epoch 336/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2705 - rmse: 0.2644 - val_loss: 0.2575 - val_rmse: 0.2520
# Epoch 337/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2706 - rmse: 0.2645 - val_loss: 0.2577 - val_rmse: 0.2523
# Epoch 338/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2700 - rmse: 0.2661 - val_loss: 0.2572 - val_rmse: 0.2514
# Epoch 339/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2709 - rmse: 0.2649 - val_loss: 0.2574 - val_rmse: 0.2519
# Epoch 340/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2712 - rmse: 0.2645 - val_loss: 0.2572 - val_rmse: 0.2513
# Epoch 341/350
# 27/27 [==============================] - 0s 4ms/step - loss: 0.2686 - rmse: 0.2607 - val_loss: 0.2633 - val_rmse: 0.2565
# Epoch 342/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2688 - rmse: 0.2620 - val_loss: 0.2573 - val_rmse: 0.2515
# Epoch 343/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2698 - rmse: 0.2631 - val_loss: 0.2571 - val_rmse: 0.2513
# Epoch 344/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2695 - rmse: 0.2632 - val_loss: 0.2592 - val_rmse: 0.2538
# Epoch 345/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2693 - rmse: 0.2621 - val_loss: 0.2574 - val_rmse: 0.2519
# Epoch 346/350
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2697 - rmse: 0.2630 - val_loss: 0.2576 - val_rmse: 0.2515
# Epoch 347/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2683 - rmse: 0.2621 - val_loss: 0.2576 - val_rmse: 0.2512
# Epoch 348/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2672 - rmse: 0.2614 - val_loss: 0.2570 - val_rmse: 0.2512
# Epoch 349/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2683 - rmse: 0.2619 - val_loss: 0.2588 - val_rmse: 0.2525
# Epoch 350/350
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2686 - rmse: 0.2615 - val_loss: 0.2571 - val_rmse: 0.2511

# %%
# acc = history.history['action_output_accuracy']
# val_acc = history.history['val_action_output_accuracy']

acc = history.history['rmse']
val_acc = history.history['val_rmse']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
_ = model.evaluate(x=testX, y={'rate_output': testRateY})
# Out:
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2571 - rmse: 0.2511

# %%
# Save the entire model as a SavedModel.
# model.save('./data/'+map_dir+'/humanModel_v2.h5')

# %%
# new_model = tf.keras.models.load_model('./data/humanModel/mode_v0')

# # Check its architecture
# new_model.summary()

# %% [markdown]
# ### Predict on new data

# %%
path = "./data/humanModel_v1_dataset/32_1/-Ms8axULhIjj8UI3-s6g_25.png"

img = keras.preprocessing.image.load_img(
    path, target_size=(IMG_SIZE, IMG_SIZE)
)
img_array = tf.keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch
img_array = img_array/255
predictions = model.predict(img_array)

print(
    "This image with rate of {}".format(predictions[0] * 7)
)
# Out:
# This image with rate of [3.0342083]
